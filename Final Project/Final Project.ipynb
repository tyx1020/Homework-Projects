# %% [markdown]
# # The empirical analysis of CAPM in SSE 180 Index

# %% [markdown]
# ## Introduction for SSE 180 Index
#
# The SSE 180 Index (also known as SSE Component Index) refers to the Shanghai Stock Exchange's adjustment and renaming of the original SSE 30 Index. The sample stocks of SSE 180 are the most representative samples of all A-share stocks, and have been officially released since July 1, 2002.As the core of SSE index series, the preparation plan of SSE 180 index aims to establish a benchmark index that reflects the general situation and operation of Shanghai securities market, is operable and investable, and can be used as the investment evaluation criterion and the basis of financial derivatives.

# %% [markdown]
# ## Overview of CAPM theoretical framework
#
# CPM model was built on the earlier work on diversification and modern portfolio theory, which was later improved by Sharpe, Markowitz and Merton Miller. The CAPM developed in the 1960s was a true revolution in financial theory, due to their contribution, William F. Sharpe received the Nobel prize in Economic Sciences in 1990 This Model basically is for estimating the capital assets using a linear equilibrium model of returns on investments that explains returns above risk-free rate using covariance with the overall market. (Džaja & Aljinović,2013). In market equilibrium the CAPM expresses the relationship between an asset’s expected return and so-called systematic risk beta in a liner function. (Sharpe, Litner, Mossin, 1966).. CAPM predicts that the expected return on an asset equals the risk-free rate plus a risk premium, it is linearly related to systematic risk measured by the assets’ beta. (Basu and Chawla, 2010). Due to the simplicity and rationality of CAPM, CAPM still remains very popular in many situations.
#
# In the development of the asset pricing model, the assumptions of the models are( Džaja Aljinović,2013)( Basu& Chawla,2008)( Blac ,Jensen& Scholes,1972)
#
# 1)Investors are risk averse and willing to maximize their expected rate of return over a period
#
# 2)Investors prefer a portfolio with higher returns
#
# 3)Free to lend and borrow with a risk-free interest
#
# 4)The property is indefinitely divisible
#
# 5)Trade without transaction or taxation costs.

# %% [markdown]
# ## Methodology
#
# In empirical analysis, this model is expressed:
#
#                                      R_p=R_f+β_p (R_m-R_f )+ε_p   (1)
#
# Where R_p  is the expected return of individual or portfolio stock in real estate industry, 𝑅𝑓 is a risk-free interest rate, 𝑅𝑚 represents the expected return of a market portfolio, 𝛽𝑝 measures the systematic risk of individual stock or market portfolio and 𝜀𝑝 is the stochastic error term. In this paper, CAPM is used to analyze the Shanghai property stock market and test whether the effectiveness of this model is verified.
#
# This paper is to use time series regression based on CAPM model to make estimation about the individual and portfolio β, which will be useful to understand the risk about Shanghai real estate market; cross sectional regression-based method developed by Black, Jensen and Scholes (1972) is to verify the relationship between risk and expected return.
#
# The detailed steps are: First, separate the whole time range from May 1st, 2010 to May 1st, 2019 into three periods; Second: Use the data in the first period to calculate the beta for individual stock; Third, rank the individual beta of each stock from lowest to highest, and make different portfolios; Fourth: use the data of second term to estimate the portfolio beta; fifth, make the cross sectional regression using the third period data coupled with these portfolio betas to determine the relationships between expected return and risk. (Tao Zhao, 2001) (Wang and Geng, 2012) (Zhu, 2010)

# %% [markdown]
# ## Data
# The data is collected from BaoStock, this is a free, open source securities data platform providing a large number of accurate, complete securities historical, financial data of public companies. Data information is obtained through python to meet the data requirements for econometric research.
# This paper selects 30 stocks from the Stock pool of SSE 180 Index from december, 2013 to december 30,2019, daily yield of trading days are almost six years. The 30 sample stocks gernerally cover the national economy including steel, real estate, finance, culture, medicine, energy, communications,transportation, software, agriculture, and so on. Also,the trading days were basically maintained for more than 1,400 days during the observation period. In general, the sample can reflect the overall operation of the market and China's securities marketand in line with the hypothesis of CAPM.
#
# Here, SSE 180 is regarded as the market portfolio index and the return on stock of SSE 180 as the return of market portfolio. The Chinese researchers normally will either do the split-adjusted share prices about the data in stock markets (Wang& Geng, 2012), or reverse split-adjusted share prices (Liao& Wang, 2003) (Zhao, 2013). In this paper, all the data are collected using the reverse split-adjusted share prices, this is to consider the influence of dividend, allotment and stock segmentation on the data (Zhao, 2013).
# Regarding the return on every stock, there are two methods of calculation, one is logarithmic algorithm, using this way( Sakouvogui and Nganje, 2019), the data processed is approximately normal distribution, which is useful to improve the stability of time series; another is to subtract the closing price of the specific stock at the ending term and the initial closing price and then divide by the beginning closing price. (Zhao, 2013) (Wang & Geng 2012)
#
# Here, in order to ensure the stability of time series, logarithmic algorithm is used to calculate the daily return about stocks.
#
#                                    R_it=Ln(P_it/P_(i(t-1)) ) (2)
#
# Where, 𝑃𝑖𝑡 is the closing price of stock i at moment t, 𝑃𝑖(𝑡−1) is the closing price at moment t-1.

# %% [markdown]
# # Estimation for individual stock
# Rewrite the equation (1) into (3), Use Single Index Model estimation:
#
#                             R_it−R_f=α_i+β_i(R_mt−R_f) +ε_it (3)
#
# Where R_it is the daily return of stock i at time t; R_mt is the return of market portfolio; R_f is the return of the risk-free asset, here R_f equates 0.009027% (one-year deposit rate on bank of China/360) as Chinese researchers basically regard the deposit rate as risk free asset by default. (Liao and Shen, 2004).

# %%
import pandas as pd
df = pd.read_csv ('final .csv') 
print(df.shape)     # read the row 
print(df.columns)   # read the columns 
print(df.head(3))   # print the first row 
print(df.tail(3))   # print the last row to check the missing variables
# Out:
# (2189, 33)
# Index(['date', 'sse180', 'rate', 'sh.600009', 'sh.600010', 'sh.600295',
#        'sh.600019', 'sh.600028', 'sh.600031', 'sh.600036', 'sh.600048',
#        'sh.600050', 'sh.600066', 'sh.600068', 'sh.600085', 'sh.600111',
#        'sh.601628', 'sh.600150', 'sh.600196', 'sh.600295.1', 'sh.600406',
#        'sh.601933', 'sh.600536', 'sh.600547', 'sh.600598', 'sh.600600',
#        'sh.600690', 'sh.600875', 'sh.600887', 'sh.600895', 'sh.601006',
#        'sh.601877', 'sh.601899'],
#       dtype='object')
#          date    sse180    rate  sh.600009  sh.600010  sh.600295  sh.600019  \
# 0  2011-01-04  6651.797  0.0001      12.37       3.91      19.79       6.55
# 1  2011-01-05  6625.325  0.0001      13.09       3.84      20.06       6.45
# 2  2011-01-06  6589.212  0.0001      13.17       3.84      20.78       6.46
#
#    sh.600028  sh.600031  sh.600036  ...  sh.600547  sh.600598  sh.600600  \
# 0       8.20      21.63      13.02  ...      53.00      13.45      35.03
# 1       8.11      22.00      12.97  ...      50.66      13.49      34.39
# 2       8.08      21.52      12.90  ...      50.05      13.57      34.47
#
#    sh.600690  sh.600875  sh.600887  sh.600895  sh.601006  sh.601877  sh.601899
# 0      28.00      35.01      39.15       8.99       7.92      24.18       8.35
# 1      27.86      35.91      38.91       8.95       7.84      24.58       8.11
# 2      27.70      34.80      36.88       8.98       7.85      24.22       7.99
#
# [3 rows x 33 columns]
#             date    sse180    rate  sh.600009  sh.600010  sh.600295  \
# 2186  2019-12-27  8723.605  0.0001      77.26       1.32       8.79
# 2187  2019-12-30  8859.993  0.0001      77.86       1.32       8.93
# 2188  2019-12-31  8877.768  0.0001      78.75       1.32       9.02
#
#       sh.600019  sh.600028  sh.600031  sh.600036  ...  sh.600547  sh.600598  \
# 2186       5.68       5.05      16.65      37.86  ...      32.31       9.57
# 2187       5.75       5.08      16.78      37.83  ...      32.12       9.69
# 2188       5.74       5.11      17.05      37.58  ...      32.62       9.74
#
#       sh.600600  sh.600690  sh.600875  sh.600887  sh.600895  sh.601006  \
# 2186      50.45      19.45       9.14      30.64      15.01       8.10
# 2187      51.09      19.31       9.17      30.83      15.32       8.22
# 2188      51.00      19.50       9.19      30.94      15.31       8.21
#
#       sh.601877  sh.601899
# 2186      25.95       4.46
# 2187      26.91       4.49
# 2188      26.80       4.59
#
# [3 rows x 33 columns]

# %% [markdown]
# #### Split the data into three periods and save as csv
# #### First Period from 2013-10-08 to 2015-10-08

# %%
# df[(df['date']>='20131008')(df['date']<='20151008')]
mask = (df['date'] > '2013-10-06') & (df['date'] <='2015-10-08' )
# mask = (df['date'] > '10-08-2013') & (df['date'] <='10-08-2015' )
df = df.loc[mask]
df.loc[mask].to_csv('final_first period')
df
# Out:
#             date    sse180    rate  sh.600009  sh.600010  sh.600295  \
# 664   2013-10-08  5275.141  0.0001      14.98       4.08       6.99
# 665   2013-10-09  5298.426  0.0001      15.15       4.05       6.98
# 666   2013-10-10  5228.953  0.0001      14.67       4.03       6.80
# 667   2013-10-11  5327.928  0.0001      15.25       4.08       6.99
# 668   2013-10-14  5326.885  0.0001      15.87       4.10       7.18
# ...          ...       ...     ...        ...        ...        ...
# 1149  2015-09-25  7125.868  0.0001      28.17       3.64       7.11
# 1150  2015-09-28  7119.292  0.0001      28.23       3.66       7.21
# 1151  2015-09-29  6976.287  0.0001      27.68       3.53       7.04
# 1152  2015-09-30  7030.858  0.0001      27.72       3.55       7.25
# 1153  2015-10-08  7216.037  0.0001      28.65       3.64       7.50
#
#       sh.600019  sh.600028  sh.600031  sh.600036  ...  sh.600547  sh.600598  \
# 664        4.24       4.47       7.64      10.91  ...      22.25      12.23
# 665        4.23       4.49       7.61      10.96  ...      22.14      13.45
# 666        4.20       4.44       7.44      10.78  ...      21.79      12.94
# 667        4.25       4.47       7.58      10.94  ...      21.93      12.75
# 668        4.26       4.45       7.74      10.80  ...      21.72      13.34
# ...         ...        ...        ...        ...  ...        ...        ...
# 1149       5.56       4.87       6.44      17.72  ...      17.32      13.53
# 1150       5.60       4.83       6.47      17.51  ...      17.32      13.71
# 1151       5.47       4.72       6.32      17.44  ...      17.32      13.74
# 1152       5.59       4.74       6.36      17.77  ...      17.32      14.32
# 1153       5.77       4.89       6.58      17.73  ...      18.03      15.75
#
#       sh.600600  sh.600690  sh.600875  sh.600887  sh.600895  sh.601006  \
# 664       42.65      13.81      11.96      44.90       8.55       7.14
# 665       42.32      14.31      11.89      46.31       8.55       7.06
# 666       41.90      15.74      11.73      46.76       8.48       7.00
# 667       43.46      15.82      12.07      46.36       9.00       7.09
# 668       46.87      15.95      12.29      45.43       8.82       7.30
# ...         ...        ...        ...        ...        ...        ...
# 1149      31.46       9.43      12.64      15.40      20.42       9.09
# 1150      31.97       9.37      12.74      15.42      20.28       9.07
# 1151      31.94       9.03      12.33      15.27      19.29       8.82
# 1152      32.14       9.06      12.50      15.38      19.02       8.83
# 1153      32.42       9.34      13.27      15.86      19.85       9.02
#
#       sh.601877  sh.601899
# 664       22.62       2.60
# 665       22.75       2.59
# 666       22.88       2.57
# 667       23.15       2.59
# 668       25.47       2.59
# ...         ...        ...
# 1149      30.62       3.51
# 1150      30.62       3.47
# 1151      30.62       3.37
# 1152      30.62       3.38
# 1153      30.62       3.48
#
# [490 rows x 33 columns]

# %% [markdown]
# #### Second Period from 2015-10-08 to 2017-10-08

# %%
# df[(df['date']>='20131008')(df['date']<='20151008')]
import pandas as pd
df = pd.read_csv ('final .csv') 
mask = (df['date'] > '2015-10-06') & (df['date'] <='2017-10-09' )
# mask = (df['date'] > '10-08-2013') & (df['date'] <='10-08-2015' )
df = df.loc[mask]
df.loc[mask].to_csv('final_second period')
df
# Out:
#             date    sse180    rate  sh.600009  sh.600010  sh.600295  \
# 1153  2015-10-08  7216.037  0.0001      28.65       3.64       7.50
# 1154  2015-10-09  7314.600  0.0001      28.57       3.70       7.55
# 1155  2015-10-12  7531.195  0.0001      28.57       3.86       7.81
# 1156  2015-10-13  7522.679  0.0001      29.38       3.87       7.91
# 1157  2015-10-14  7449.195  0.0001      28.68       4.20       7.74
# ...          ...       ...     ...        ...        ...        ...
# 1638  2017-09-26  8293.150  0.0001      38.43       2.70      14.74
# 1639  2017-09-27  8271.729  0.0001      38.15       2.72      15.15
# 1640  2017-09-28  8269.078  0.0001      38.33       2.70      14.73
# 1641  2017-09-29  8297.697  0.0001      37.98       2.70      14.70
# 1642  2017-10-09  8366.398  0.0001      38.56       2.72      14.81
#
#       sh.600019  sh.600028  sh.600031  sh.600036  ...  sh.600547  sh.600598  \
# 1153       5.77       4.89       6.58      17.73  ...      18.03      15.75
# 1154       5.80       5.03       6.70      17.96  ...      19.39      16.19
# 1155       5.98       5.15       7.00      18.19  ...      20.02      16.81
# 1156       5.94       5.09       6.93      18.06  ...      19.45      17.58
# 1157       5.88       5.07       6.76      17.85  ...      19.48      16.79
# ...         ...        ...        ...        ...  ...        ...        ...
# 1638       7.27       5.96       7.35      25.71  ...      31.74      11.75
# 1639       7.46       5.92       7.55      25.40  ...      31.38      11.75
# 1640       7.34       5.90       7.48      25.20  ...      31.19      11.96
# 1641       7.39       5.90       7.65      25.55  ...      31.43      11.93
# 1642       7.46       5.87       7.77      26.08  ...      31.56      12.34
#
#       sh.600600  sh.600690  sh.600875  sh.600887  sh.600895  sh.601006  \
# 1153      32.42       9.34      13.27      15.86      19.85       9.02
# 1154      32.44       9.37      13.54      15.86      19.97       9.08
# 1155      33.56       9.72      14.23      16.16      20.80       9.35
# 1156      33.60       9.72      14.80      16.29      21.15       9.28
# 1157      33.51       9.56      14.50      15.99      20.91       9.15
# ...         ...        ...        ...        ...        ...        ...
# 1638      30.51      14.52      10.40      25.80      16.82       8.91
# 1639      30.56      14.80      10.42      25.44      16.75       8.84
# 1640      30.59      14.91      10.42      26.40      16.76       8.85
# 1641      30.81      15.09      10.43      27.50      16.77       8.75
# 1642      31.10      15.35      10.51      27.79      16.81       8.87
#
#       sh.601877  sh.601899
# 1153      30.62       3.48
# 1154      30.62       3.55
# 1155      30.62       3.74
# 1156      30.62       3.70
# 1157      30.02       3.67
# ...         ...        ...
# 1638      21.56       3.93
# 1639      21.92       3.91
# 1640      21.50       3.87
# 1641      21.39       3.87
# 1642      22.18       3.90
#
# [490 rows x 33 columns]

# %% [markdown]
# #### Third Period from 2017-10-08 to 2019-10-08

# %%
# df[(df['date']>='20131008')(df['date']<='20151008')]
import pandas as pd
df = pd.read_csv ('final .csv') 
mask = (df['date'] > '2017-10-06') & (df['date'] <='2019-10-08' )
# mask = (df['date'] > '10-08-2013') & (df['date'] <='10-08-2015' )
df = df.loc[mask]
df.loc[mask].to_csv('final_third period')
df
# Out:
#             date    sse180    rate  sh.600009  sh.600010  sh.600295  \
# 1642  2017-10-09  8366.398  0.0001      38.56       2.72      14.81
# 1643  2017-10-10  8369.725  0.0001      37.82       2.69      14.63
# 1644  2017-10-11  8391.506  0.0001      38.63       2.67      14.40
# 1645  2017-10-12  8415.264  0.0001      39.99       2.67      14.14
# 1646  2017-10-13  8414.460  0.0001      40.04       2.66      14.14
# ...          ...       ...     ...        ...        ...        ...
# 2124  2019-09-25  8527.464  0.0001      80.68       1.48       7.89
# 2125  2019-09-26  8491.745  0.0001      80.35       1.47       7.78
# 2126  2019-09-27  8495.943  0.0001      79.93       1.46       7.77
# 2127  2019-09-30  8409.486  0.0001      79.78       1.46       7.92
# 2128  2019-10-08  8459.011  0.0001      77.78       1.47       7.85
#
#       sh.600019  sh.600028  sh.600031  sh.600036  ...  sh.600547  sh.600598  \
# 1642       7.46       5.87       7.77      26.08  ...      31.56      12.34
# 1643       7.34       5.85       7.79      26.12  ...      31.49      12.67
# 1644       7.28       5.86       7.76      26.04  ...      31.20      12.55
# 1645       7.37       5.82       7.81      26.37  ...      31.30      12.53
# 1646       7.53       5.81       7.90      26.20  ...      31.18      12.89
# ...         ...        ...        ...        ...  ...        ...        ...
# 2124       6.01       5.01      14.40      34.35  ...      37.32       9.69
# 2125       6.03       5.00      14.39      35.22  ...      34.18       9.70
# 2126       5.92       4.99      14.41      35.20  ...      34.05       9.74
# 2127       5.91       5.02      14.28      34.75  ...      33.89       9.69
# 2128       5.90       5.00      14.55      34.81  ...      33.69       9.78
#
#       sh.600600  sh.600690  sh.600875  sh.600887  sh.600895  sh.601006  \
# 1642      31.10      15.35      10.51      27.79      16.81       8.87
# 1643      31.19      14.76      10.56      27.59      16.85       9.02
# 1644      31.44      14.80      10.49      28.57      16.95       9.02
# 1645      31.29      15.62      10.35      28.49      17.09       9.06
# 1646      32.85      15.93      10.45      27.60      17.08       8.97
# ...         ...        ...        ...        ...        ...        ...
# 2124      49.13      15.15       9.30      27.84      16.03       7.67
# 2125      48.86      15.25       9.09      28.05      15.51       7.66
# 2126      48.75      15.37       9.16      28.29      15.53       7.61
# 2127      48.50      15.30       9.21      28.52      15.50       7.59
# 2128      49.37      15.55       9.12      28.54      15.48       7.55
#
#       sh.601877  sh.601899
# 1642      22.18       3.90
# 1643      22.63       3.90
# 1644      22.21       3.87
# 1645      23.24       3.87
# 1646      23.29       3.90
# ...         ...        ...
# 2124      22.14       3.41
# 2125      22.06       3.31
# 2126      22.01       3.29
# 2127      21.83       3.27
# 2128      21.89       3.26
#
# [487 rows x 33 columns]

# %% [markdown]
# #### Caculate the percentage change  and obtain the logarithm of them in order to do the OLS about individual stock

# %%
# df['sse180'].div(df['sse180'].shift(1))
import pandas as pd
df = pd.read_csv ('final .csv',index_col = "date",parse_dates = True)
# print(df['sse180'].div(df['sse180'].shift(1)))

# %%
df.pct_change( )
# Out:
#               sse180  rate  sh.600009  sh.600010  sh.600295  sh.600019  \
# date
# 2011-01-04       NaN   NaN        NaN        NaN        NaN        NaN
# 2011-01-05 -0.003980   0.0   0.058205  -0.017903   0.013643  -0.015267
# 2011-01-06 -0.005451   0.0   0.006112   0.000000   0.035892   0.001550
# 2011-01-07  0.004825   0.0  -0.013667   0.005208  -0.039461   0.015480
# 2011-01-10 -0.017165   0.0  -0.030023  -0.025907  -0.017535  -0.006098
# ...              ...   ...        ...        ...        ...        ...
# 2019-12-25 -0.001614   0.0  -0.002956  -0.007634   0.001159  -0.010638
# 2019-12-26  0.009237   0.0   0.003481   0.000000   0.015046   0.008961
# 2019-12-27  0.000658   0.0  -0.007451   0.015385   0.002281   0.008881
# 2019-12-30  0.015634   0.0   0.007766   0.000000   0.015927   0.012324
# 2019-12-31  0.002006   0.0   0.011431   0.000000   0.010078  -0.001739
#
#             sh.600028  sh.600031  sh.600036  sh.600048  ...  sh.600547  \
# date                                                    ...
# 2011-01-04        NaN        NaN        NaN        NaN  ...        NaN
# 2011-01-05  -0.010976   0.017106  -0.003840   0.003582  ...  -0.044151
# 2011-01-06  -0.003699  -0.021818  -0.005397   0.026410  ...  -0.012041
# 2011-01-07   0.012376  -0.012546   0.027132   0.000695  ...  -0.021179
# 2011-01-10   0.002445  -0.012235  -0.017358  -0.029882  ...   0.004287
# ...               ...        ...        ...        ...  ...        ...
# 2019-12-25  -0.001992   0.038920  -0.005788  -0.007138  ...   0.007253
# 2019-12-26   0.001996   0.001813   0.008203   0.039869  ...   0.000000
# 2019-12-27   0.005976   0.004222  -0.006299  -0.002514  ...   0.011584
# 2019-12-30   0.005941   0.007808  -0.000792   0.025205  ...  -0.005881
# 2019-12-31   0.005906   0.016091  -0.006609  -0.005532  ...   0.015567
#
#             sh.600598  sh.600600  sh.600690  sh.600875  sh.600887  sh.600895  \
# date
# 2011-01-04        NaN        NaN        NaN        NaN        NaN        NaN
# 2011-01-05   0.002974  -0.018270  -0.005000   0.025707  -0.006130  -0.004449
# 2011-01-06   0.005930   0.002326  -0.005743  -0.030911  -0.052172   0.003352
# 2011-01-07  -0.014738   0.017116  -0.000722  -0.030747  -0.004338   0.012249
# 2011-01-10   0.004488  -0.030519  -0.028540  -0.002965  -0.025327  -0.023102
# ...               ...        ...        ...        ...        ...        ...
# 2019-12-25  -0.007269  -0.009145  -0.014941  -0.008686  -0.008598  -0.002717
# 2019-12-26   0.002092   0.010634   0.040795   0.016429   0.004670   0.023161
# 2019-12-27  -0.001044   0.001588  -0.022613  -0.015086   0.017264  -0.000666
# 2019-12-30   0.012539   0.012686  -0.007198   0.003282   0.006201   0.020653
# 2019-12-31   0.005160  -0.001762   0.009839   0.002181   0.003568  -0.000653
#
#             sh.601006  sh.601877  sh.601899
# date
# 2011-01-04        NaN        NaN        NaN
# 2011-01-05  -0.010101   0.016543  -0.028743
# 2011-01-06   0.001276  -0.014646  -0.014797
# 2011-01-07   0.006369  -0.007845  -0.012516
# 2011-01-10   0.005063  -0.006242  -0.013942
# ...               ...        ...        ...
# 2019-12-25   0.003708  -0.001543   0.004854
# 2019-12-26   0.001232   0.013138   0.012077
# 2019-12-27  -0.003690  -0.010297   0.064439
# 2019-12-30   0.014815   0.036994   0.006726
# 2019-12-31  -0.001217  -0.004088   0.022272
#
# [2189 rows x 32 columns]

# %%
# data = df.pct_change()
# data.to_csv('sse.csv')

# %%
import pandas as pd
df = pd.read_csv ('sse1.csv') 
# df['sse180-rate'] = df["sse180"] - df["rate"]
df['sse180'] = df["sse180"] - df["rate"]
df['sh.600009'] = df["sh.600009"] - df["rate"]
df['sh.600010'] = df["sh.600010"] - df["rate"]
df['sh.600295'] = df["sh.600295"] - df["rate"]
df['sh.600028'] = df["sh.600028"] - df["rate"]
df['sh.600031'] = df["sh.600031"] - df["rate"]
df['sh.600036'] = df["sh.600036"] - df["rate"]
df['sh.600048'] = df["sh.600048"] - df["rate"]
df['sh.600050'] = df["sh.600050"] - df["rate"]
df['sh.600066'] = df["sh.600066"] - df["rate"]
df['sh.600068'] = df["sh.600068"] - df["rate"]
df['sh.600085'] = df["sh.600085"] - df["rate"]
df['sh.600111'] = df["sh.600111"] - df["rate"]
df['sh.601628'] = df["sh.601628"] - df["rate"]
df['sh.600150'] = df["sh.600150"] - df["rate"]
df['sh.600196'] = df["sh.600196"] - df["rate"]
df['sh.600295.1'] = df["sh.600295.1"] - df["rate"]
df['sh.600406'] = df["sh.600406"] - df["rate"]
df['sh.601933'] = df["sh.601933"] - df["rate"]
df['sh.600536'] = df["sh.600536"] - df["rate"]
df['sh.600547'] = df["sh.600547"] - df["rate"]
df['sh.600598'] = df["sh.600598"] - df["rate"]
df['sh.600600'] = df["sh.600600"] - df["rate"]
df['sh.600690'] = df["sh.600690"] - df["rate"]
df['sh.600875'] = df["sh.600875"] - df["rate"]
df['sh.600887'] = df["sh.600887"] - df["rate"]
df['sh.600895'] = df["sh.600895"] - df["rate"]
df['sh.601006'] = df["sh.601006"] - df["rate"]
df['sh.601877'] = df["sh.601877"] - df["rate"]
df['sh.601899'] = df["sh.601899"] - df["rate"]
df
# Out:
#       Unnamed: 0        date    sse180     rate  sh.600009  sh.600010  \
# 0              1  2011-01-04       NaN      NaN        NaN        NaN
# 1              2  2011-01-05 -0.004070  0.00009   0.058115  -0.017993
# 2              3  2011-01-06 -0.005541  0.00009   0.006021  -0.000090
# 3              4  2011-01-07  0.004735  0.00009  -0.013758   0.005118
# 4              5  2011-01-10 -0.017255  0.00009  -0.030113  -0.025997
# ...          ...         ...       ...      ...        ...        ...
# 2184        2185  2019-12-25 -0.001704  0.00009  -0.003047  -0.007724
# 2185        2186  2019-12-26  0.009147  0.00009   0.003390  -0.000090
# 2186        2187  2019-12-27  0.000567  0.00009  -0.007541   0.015294
# 2187        2188  2019-12-30  0.015544  0.00009   0.007676  -0.000090
# 2188        2189  2019-12-31  0.001916  0.00009   0.011341  -0.000090
#
#       sh.600295  sh.600019  sh.600028  sh.600031  ...  sh.600547  sh.600598  \
# 0           NaN        NaN        NaN        NaN  ...        NaN        NaN
# 1      0.013553  -0.015267  -0.011066   0.017016  ...  -0.044241   0.002884
# 2      0.035802   0.001550  -0.003789  -0.021908  ...  -0.012131   0.005840
# 3     -0.039551   0.015480   0.012286  -0.012637  ...  -0.021269  -0.014829
# 4     -0.017625  -0.006098   0.002355  -0.012326  ...   0.004196   0.004397
# ...         ...        ...        ...        ...  ...        ...        ...
# 2184   0.001068  -0.010638  -0.002082   0.038830  ...   0.007163  -0.007359
# 2185   0.014956   0.008961   0.001906   0.001722  ...  -0.000090   0.002002
# 2186   0.002190   0.008881   0.005886   0.004132  ...   0.011494  -0.001134
# 2187   0.015837   0.012324   0.005850   0.007718  ...  -0.005971   0.012449
# 2188   0.009988  -0.001739   0.005815   0.016000  ...   0.015476   0.005070
#
#       sh.600600  sh.600690  sh.600875  sh.600887  sh.600895  sh.601006  \
# 0           NaN        NaN        NaN        NaN        NaN        NaN
# 1     -0.018360  -0.005090   0.025617  -0.006221  -0.004540  -0.010191
# 2      0.002236  -0.005833  -0.031001  -0.052262   0.003262   0.001185
# 3      0.017026  -0.000812  -0.030837  -0.004429   0.012159   0.006279
# 4     -0.030609  -0.028631  -0.003055  -0.025417  -0.023193   0.004973
# ...         ...        ...        ...        ...        ...        ...
# 2184  -0.009235  -0.015031  -0.008776  -0.008688  -0.002808   0.003618
# 2185   0.010544   0.040705   0.016339   0.004580   0.023070   0.001141
# 2186   0.001498  -0.022703  -0.015176   0.017174  -0.000756  -0.003780
# 2187   0.012596  -0.007288   0.003192   0.006111   0.020563   0.014725
# 2188  -0.001852   0.009749   0.002091   0.003478  -0.000743  -0.001307
#
#       sh.601877  sh.601899
# 0           NaN        NaN
# 1      0.016452  -0.028833
# 2     -0.014736  -0.014887
# 3     -0.007935  -0.012606
# 4     -0.006332  -0.014032
# ...         ...        ...
# 2184  -0.001633   0.004764
# 2185   0.013047   0.011987
# 2186  -0.010388   0.064349
# 2187   0.036904   0.006636
# 2188  -0.004178   0.022181
#
# [2189 rows x 34 columns]

# %%
data1 = df
data1.to_csv('sse4.csv')

# %%
from regression import Regression
reg = Regression()
print(reg)
# Out:
# You created an instance of Stats
# <regression.Regression object at 0x0000025ADAD08280>

# %%
import pandas as pd  
import copy
from stats import *    
  
class Regression:  
    def __init__(self):  
        self.stats = stats()  
          
    def OLS(self, reg_name, data, y_name, beta_names, 
            min_val = 0,  
                max_val = None, constant = True):  
        self.min_val = min_val  
        if max_val != None:  
            self.max_val = max_val  
        else:  
            self.max_val = len(data)  
        self.reg_name = reg_name  
        self.y_name = y_name  
        self.beta_names = copy.copy(beta_names)
        self.data = data.copy()  
        if constant:  
            self.add_constant()  
  
    def add_constant(self):  
        self.data["Constant"] = 1  
        self.beta_names.append("Constant")

# %%
import pandas as pd
from regression import Regression
reg = Regression()
print(reg)
reg
# Out:
# You created an instance of Stats
# <regression.Regression object at 0x0000025AE2213AF0>

# %% [markdown]
# ## Step 1

# %% [markdown]
# #### Now it is time to caculate the beta for 30 indidual stocks

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
import statsmodels.api as sm

df = pd.read_csv("sse3.csv", index_col = "DATE")
X = df['sse180']
ylabes = ['sh.600009','sh.600010', 'sh.600295', 'sh.600019', 'sh.600028',
         'sh.600031' , 'sh.600036' ,'sh.600048','sh.600050','sh.600066','sh.600068',
         'sh.600085','sh.600111','sh.601628','sh.600150','sh.600196', 'sh.600295.1','sh.600406',  
          'sh.601933',  'sh.600536' ,'sh.600547','sh.600598','sh.600600', 'sh.600690' , 'sh.600875', 
          'sh.600887', 'sh.600895', 'sh.601006', 'sh.601877', 'sh.601899']
for y in ylabes:
    Y = df[y]
    est = sm.OLS(Y, X).fit()
    print(est.summary())
    print(est.params)
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600009   R-squared (uncentered):                   0.474
# Model:                            OLS   Adj. R-squared (uncentered):              0.473
# Method:                 Least Squares   F-statistic:                              440.0
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    3.79e-70
# Time:                        19:16:57   Log-Likelihood:                          1205.5
# No. Observations:                 490   AIC:                                     -2409.
# Df Residuals:                     489   BIC:                                     -2405.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         1.0127      0.048     20.975      0.000       0.918       1.108
# ==============================================================================
# Omnibus:                       80.781   Durbin-Watson:                   1.938
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              290.714
# Skew:                           0.712   Prob(JB):                     7.45e-64
# Kurtosis:                       6.494   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    1.012701
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600010   R-squared (uncentered):                   0.259
# Model:                            OLS   Adj. R-squared (uncentered):              0.258
# Method:                 Least Squares   F-statistic:                              171.3
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    9.14e-34
# Time:                        19:16:57   Log-Likelihood:                          948.16
# No. Observations:                 490   AIC:                                     -1894.
# Df Residuals:                     489   BIC:                                     -1890.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         1.0683      0.082     13.087      0.000       0.908       1.229
# ==============================================================================
# Omnibus:                      599.327   Durbin-Watson:                   1.821
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           146572.321
# Skew:                          -5.407   Prob(JB):                         0.00
# Kurtosis:                      87.036   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    1.068271
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600295   R-squared (uncentered):                   0.395
# Model:                            OLS   Adj. R-squared (uncentered):              0.394
# Method:                 Least Squares   F-statistic:                              319.8
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    2.10e-55
# Time:                        19:16:57   Log-Likelihood:                          1170.9
# No. Observations:                 490   AIC:                                     -2340.
# Df Residuals:                     489   BIC:                                     -2336.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         0.9265      0.052     17.884      0.000       0.825       1.028
# ==============================================================================
# Omnibus:                       50.877   Durbin-Watson:                   1.761
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              300.083
# Skew:                           0.129   Prob(JB):                     6.89e-66
# Kurtosis:                       6.825   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    0.926506
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600019   R-squared (uncentered):                   0.579
# Model:                            OLS   Adj. R-squared (uncentered):              0.578
# Method:                 Least Squares   F-statistic:                              671.8
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    7.55e-94
# Time:                        19:16:57   Log-Likelihood:                          1239.3
# No. Observations:                 490   AIC:                                     -2477.
# Df Residuals:                     489   BIC:                                     -2472.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         1.1679      0.045     25.919      0.000       1.079       1.256
# ==============================================================================
# Omnibus:                      168.857   Durbin-Watson:                   2.154
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              852.136
# Skew:                           1.428   Prob(JB):                    9.14e-186
# Kurtosis:                       8.795   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    1.167947
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600028   R-squared (uncentered):                   0.510
# Model:                            OLS   Adj. R-squared (uncentered):              0.509
# Method:                 Least Squares   F-statistic:                              509.5
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    7.99e-78
# Time:                        19:16:57   Log-Likelihood:                          1301.6
# No. Observations:                 490   AIC:                                     -2601.
# Df Residuals:                     489   BIC:                                     -2597.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         0.8956      0.040     22.571      0.000       0.818       0.974
# ==============================================================================
# Omnibus:                      182.810   Durbin-Watson:                   1.981
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1189.508
# Skew:                           1.471   Prob(JB):                    5.03e-259
# Kurtosis:                      10.043   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    0.895568
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600031   R-squared (uncentered):                   0.566
# Model:                            OLS   Adj. R-squared (uncentered):              0.565
# Method:                 Least Squares   F-statistic:                              637.5
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    1.17e-90
# Time:                        19:16:57   Log-Likelihood:                          1207.4
# No. Observations:                 490   AIC:                                     -2413.
# Df Residuals:                     489   BIC:                                     -2409.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         1.2142      0.048     25.249      0.000       1.120       1.309
# ==============================================================================
# Omnibus:                      113.980   Durbin-Watson:                   1.981
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              567.712
# Skew:                           0.918   Prob(JB):                    5.28e-124
# Kurtosis:                       7.943   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    1.214249
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600036   R-squared (uncentered):                   0.510
# Model:                            OLS   Adj. R-squared (uncentered):              0.509
# Method:                 Least Squares   F-statistic:                              508.8
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    9.40e-78
# Time:                        19:16:57   Log-Likelihood:                          1333.3
# No. Observations:                 490   AIC:                                     -2665.
# Df Residuals:                     489   BIC:                                     -2660.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         0.8390      0.037     22.556      0.000       0.766       0.912
# ==============================================================================
# Omnibus:                      175.826   Durbin-Watson:                   1.873
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1162.393
# Skew:                           1.398   Prob(JB):                    3.89e-253
# Kurtosis:                      10.008   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    0.839032
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600048   R-squared (uncentered):                   0.492
# Model:                            OLS   Adj. R-squared (uncentered):              0.491
# Method:                 Least Squares   F-statistic:                              473.3
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    6.66e-74
# Time:                        19:16:57   Log-Likelihood:                          1106.9
# No. Observations:                 490   AIC:                                     -2212.
# Df Residuals:                     489   BIC:                                     -2208.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         1.2844      0.059     21.756      0.000       1.168       1.400
# ==============================================================================
# Omnibus:                      568.215   Durbin-Watson:                   2.020
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           120068.959
# Skew:                          -4.940   Prob(JB):                         0.00
# Kurtosis:                      79.048   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    1.284386
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600050   R-squared (uncentered):                   0.546
# Model:                            OLS   Adj. R-squared (uncentered):              0.545
# Method:                 Least Squares   F-statistic:                              588.5
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    6.24e-86
# Time:                        19:16:57   Log-Likelihood:                          1201.5
# No. Observations:                 490   AIC:                                     -2401.
# Df Residuals:                     489   BIC:                                     -2397.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         1.1808      0.049     24.260      0.000       1.085       1.276
# ==============================================================================
# Omnibus:                      203.030   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1137.515
# Skew:                           1.728   Prob(JB):                    9.81e-248
# Kurtosis:                       9.616   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    1.180818
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600066   R-squared (uncentered):                   0.301
# Model:                            OLS   Adj. R-squared (uncentered):              0.299
# Method:                 Least Squares   F-statistic:                              210.3
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    6.89e-40
# Time:                        19:16:57   Log-Likelihood:                          1133.3
# No. Observations:                 490   AIC:                                     -2265.
# Df Residuals:                     489   BIC:                                     -2260.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         0.8111      0.056     14.500      0.000       0.701       0.921
# ==============================================================================
# Omnibus:                      440.184   Durbin-Watson:                   1.874
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            40318.993
# Skew:                          -3.374   Prob(JB):                         0.00
# Kurtosis:                      46.924   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    0.811112
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600068   R-squared (uncentered):                   0.518
# Model:                            OLS   Adj. R-squared (uncentered):              0.517
# Method:                 Least Squares   F-statistic:                              525.6
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    1.57e-79
# Time:                        19:16:57   Log-Likelihood:                          1155.7
# No. Observations:                 490   AIC:                                     -2309.
# Df Residuals:                     489   BIC:                                     -2305.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         1.2252      0.053     22.926      0.000       1.120       1.330
# ==============================================================================
# Omnibus:                      114.660   Durbin-Watson:                   1.860
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              552.144
# Skew:                           0.935   Prob(JB):                    1.27e-120
# Kurtosis:                       7.852   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    1.22521
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600085   R-squared (uncentered):                   0.485
# Model:                            OLS   Adj. R-squared (uncentered):              0.484
# Method:                 Least Squares   F-statistic:                              460.4
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    1.84e-72
# Time:                        19:16:57   Log-Likelihood:                          1218.8
# No. Observations:                 490   AIC:                                     -2436.
# Df Residuals:                     489   BIC:                                     -2431.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         1.0081      0.047     21.456      0.000       0.916       1.100
# ==============================================================================
# Omnibus:                       54.364   Durbin-Watson:                   1.921
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              266.797
# Skew:                           0.313   Prob(JB):                     1.16e-58
# Kurtosis:                       6.560   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    1.008076
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600111   R-squared (uncentered):                   0.387
# Model:                            OLS   Adj. R-squared (uncentered):              0.385
# Method:                 Least Squares   F-statistic:                              308.2
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    7.21e-54
# Time:                        19:16:57   Log-Likelihood:                          1094.3
# No. Observations:                 490   AIC:                                     -2187.
# Df Residuals:                     489   BIC:                                     -2182.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         1.0636      0.061     17.557      0.000       0.945       1.183
# ==============================================================================
# Omnibus:                      479.467   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            65325.851
# Skew:                          -3.760   Prob(JB):                         0.00
# Kurtosis:                      59.063   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    1.063649
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.601628   R-squared (uncentered):                   0.512
# Model:                            OLS   Adj. R-squared (uncentered):              0.511
# Method:                 Least Squares   F-statistic:                              512.3
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    3.95e-78
# Time:                        19:16:57   Log-Likelihood:                          1218.7
# No. Observations:                 490   AIC:                                     -2435.
# Df Residuals:                     489   BIC:                                     -2431.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         1.0636      0.047     22.635      0.000       0.971       1.156
# ==============================================================================
# Omnibus:                      147.552   Durbin-Watson:                   1.655
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              583.012
# Skew:                           1.313   Prob(JB):                    2.51e-127
# Kurtosis:                       7.654   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    1.063607
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600150   R-squared (uncentered):                   0.401
# Model:                            OLS   Adj. R-squared (uncentered):              0.400
# Method:                 Least Squares   F-statistic:                              327.5
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    2.09e-56
# Time:                        19:16:57   Log-Likelihood:                          1016.3
# No. Observations:                 490   AIC:                                     -2031.
# Df Residuals:                     489   BIC:                                     -2026.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         1.2855      0.071     18.096      0.000       1.146       1.425
# ==============================================================================
# Omnibus:                       24.181   Durbin-Watson:                   1.885
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.726
# Skew:                           0.354   Prob(JB):                     2.36e-09
# Kurtosis:                       4.202   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    1.285451
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600196   R-squared (uncentered):                   0.335
# Model:                            OLS   Adj. R-squared (uncentered):              0.334
# Method:                 Least Squares   F-statistic:                              246.8
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    2.58e-45
# Time:                        19:16:57   Log-Likelihood:                          1101.9
# No. Observations:                 490   AIC:                                     -2202.
# Df Residuals:                     489   BIC:                                     -2198.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         0.9369      0.060     15.708      0.000       0.820       1.054
# ==============================================================================
# Omnibus:                      104.535   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              309.949
# Skew:                           1.004   Prob(JB):                     4.96e-68
# Kurtosis:                       6.339   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    0.936906
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            sh.600295.1   R-squared (uncentered):                   0.395
# Model:                            OLS   Adj. R-squared (uncentered):              0.394
# Method:                 Least Squares   F-statistic:                              319.8
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    2.10e-55
# Time:                        19:16:57   Log-Likelihood:                          1170.9
# No. Observations:                 490   AIC:                                     -2340.
# Df Residuals:                     489   BIC:                                     -2336.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         0.9265      0.052     17.884      0.000       0.825       1.028
# ==============================================================================
# Omnibus:                       50.877   Durbin-Watson:                   1.761
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              300.083
# Skew:                           0.129   Prob(JB):                     6.89e-66
# Kurtosis:                       6.825   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    0.926506
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600406   R-squared (uncentered):                   0.433
# Model:                            OLS   Adj. R-squared (uncentered):              0.432
# Method:                 Least Squares   F-statistic:                              374.0
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    2.62e-62
# Time:                        19:16:57   Log-Likelihood:                          1111.1
# No. Observations:                 490   AIC:                                     -2220.
# Df Residuals:                     489   BIC:                                     -2216.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         1.1320      0.059     19.339      0.000       1.017       1.247
# ==============================================================================
# Omnibus:                       53.688   Durbin-Watson:                   1.740
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              150.230
# Skew:                           0.523   Prob(JB):                     2.39e-33
# Kurtosis:                       5.503   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    1.132
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.601933   R-squared (uncentered):                   0.211
# Model:                            OLS   Adj. R-squared (uncentered):              0.209
# Method:                 Least Squares   F-statistic:                              130.8
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    5.21e-27
# Time:                        19:16:57   Log-Likelihood:                          957.94
# No. Observations:                 490   AIC:                                     -1914.
# Df Residuals:                     489   BIC:                                     -1910.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         0.9152      0.080     11.438      0.000       0.758       1.072
# ==============================================================================
# Omnibus:                      617.359   Durbin-Watson:                   1.805
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           150575.709
# Skew:                          -5.730   Prob(JB):                         0.00
# Kurtosis:                      88.111   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    0.915207
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600536   R-squared (uncentered):                   0.145
# Model:                            OLS   Adj. R-squared (uncentered):              0.143
# Method:                 Least Squares   F-statistic:                              82.62
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    2.48e-18
# Time:                        19:16:57   Log-Likelihood:                          813.30
# No. Observations:                 490   AIC:                                     -1625.
# Df Residuals:                     489   BIC:                                     -1620.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         0.9770      0.107      9.090      0.000       0.766       1.188
# ==============================================================================
# Omnibus:                      269.508   Durbin-Watson:                   1.927
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8280.907
# Skew:                          -1.789   Prob(JB):                         0.00
# Kurtosis:                      22.819   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    0.97702
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600547   R-squared (uncentered):                   0.315
# Model:                            OLS   Adj. R-squared (uncentered):              0.313
# Method:                 Least Squares   F-statistic:                              224.6
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    4.70e-42
# Time:                        19:16:57   Log-Likelihood:                          1115.5
# No. Observations:                 490   AIC:                                     -2229.
# Df Residuals:                     489   BIC:                                     -2225.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         0.8694      0.058     14.987      0.000       0.755       0.983
# ==============================================================================
# Omnibus:                       85.047   Durbin-Watson:                   1.764
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              379.686
# Skew:                           0.682   Prob(JB):                     3.57e-83
# Kurtosis:                       7.091   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    0.869417
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600598   R-squared (uncentered):                   0.147
# Model:                            OLS   Adj. R-squared (uncentered):              0.145
# Method:                 Least Squares   F-statistic:                              84.07
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    1.33e-18
# Time:                        19:16:57   Log-Likelihood:                          939.92
# No. Observations:                 490   AIC:                                     -1878.
# Df Residuals:                     489   BIC:                                     -1874.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         0.7611      0.083      9.169      0.000       0.598       0.924
# ==============================================================================
# Omnibus:                       25.544   Durbin-Watson:                   1.627
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               72.134
# Skew:                          -0.130   Prob(JB):                     2.17e-16
# Kurtosis:                       4.862   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    0.761116
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600600   R-squared (uncentered):                   0.459
# Model:                            OLS   Adj. R-squared (uncentered):              0.458
# Method:                 Least Squares   F-statistic:                              414.6
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    3.37e-67
# Time:                        19:16:57   Log-Likelihood:                          1296.0
# No. Observations:                 490   AIC:                                     -2590.
# Df Residuals:                     489   BIC:                                     -2586.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         0.8172      0.040     20.361      0.000       0.738       0.896
# ==============================================================================
# Omnibus:                      124.865   Durbin-Watson:                   1.868
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              470.516
# Skew:                           1.113   Prob(JB):                    6.74e-103
# Kurtosis:                       7.253   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    0.817151
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600690   R-squared (uncentered):                   0.267
# Model:                            OLS   Adj. R-squared (uncentered):              0.266
# Method:                 Least Squares   F-statistic:                              178.2
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    7.00e-35
# Time:                        19:16:57   Log-Likelihood:                          981.48
# No. Observations:                 490   AIC:                                     -1961.
# Df Residuals:                     489   BIC:                                     -1957.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         1.0180      0.076     13.350      0.000       0.868       1.168
# ==============================================================================
# Omnibus:                      746.830   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           357900.834
# Skew:                          -8.037   Prob(JB):                         0.00
# Kurtosis:                     134.421   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    1.018034
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600875   R-squared (uncentered):                   0.507
# Model:                            OLS   Adj. R-squared (uncentered):              0.506
# Method:                 Least Squares   F-statistic:                              502.6
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    4.30e-77
# Time:                        19:16:57   Log-Likelihood:                          1126.8
# No. Observations:                 490   AIC:                                     -2252.
# Df Residuals:                     489   BIC:                                     -2247.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         1.2709      0.057     22.419      0.000       1.160       1.382
# ==============================================================================
# Omnibus:                       56.990   Durbin-Watson:                   2.108
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              156.098
# Skew:                           0.565   Prob(JB):                     1.27e-34
# Kurtosis:                       5.524   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    1.270881
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600887   R-squared (uncentered):                   0.271
# Model:                            OLS   Adj. R-squared (uncentered):              0.269
# Method:                 Least Squares   F-statistic:                              181.8
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    1.89e-35
# Time:                        19:16:57   Log-Likelihood:                          973.11
# No. Observations:                 490   AIC:                                     -1944.
# Df Residuals:                     489   BIC:                                     -1940.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         1.0459      0.078     13.482      0.000       0.893       1.198
# ==============================================================================
# Omnibus:                      689.294   Durbin-Watson:                   1.943
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           163930.798
# Skew:                          -7.144   Prob(JB):                         0.00
# Kurtosis:                      91.460   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    1.045878
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.600895   R-squared (uncentered):                   0.342
# Model:                            OLS   Adj. R-squared (uncentered):              0.341
# Method:                 Least Squares   F-statistic:                              254.0
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    2.34e-46
# Time:                        19:16:57   Log-Likelihood:                          1007.0
# No. Observations:                 490   AIC:                                     -2012.
# Df Residuals:                     489   BIC:                                     -2008.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         1.1537      0.072     15.937      0.000       1.012       1.296
# ==============================================================================
# Omnibus:                       36.148   Durbin-Watson:                   1.936
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              103.978
# Skew:                           0.306   Prob(JB):                     2.64e-23
# Kurtosis:                       5.172   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    1.153745
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.601006   R-squared (uncentered):                   0.532
# Model:                            OLS   Adj. R-squared (uncentered):              0.531
# Method:                 Least Squares   F-statistic:                              556.7
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    9.67e-83
# Time:                        19:16:57   Log-Likelihood:                          1246.2
# No. Observations:                 490   AIC:                                     -2490.
# Df Residuals:                     489   BIC:                                     -2486.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         1.0483      0.044     23.594      0.000       0.961       1.136
# ==============================================================================
# Omnibus:                       82.244   Durbin-Watson:                   2.049
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              335.765
# Skew:                           0.685   Prob(JB):                     1.23e-73
# Kurtosis:                       6.817   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    1.048329
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.601877   R-squared (uncentered):                   0.047
# Model:                            OLS   Adj. R-squared (uncentered):              0.045
# Method:                 Least Squares   F-statistic:                              24.27
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    1.15e-06
# Time:                        19:16:57   Log-Likelihood:                          1137.4
# No. Observations:                 490   AIC:                                     -2273.
# Df Residuals:                     489   BIC:                                     -2269.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         0.2733      0.055      4.927      0.000       0.164       0.382
# ==============================================================================
# Omnibus:                      270.953   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10411.606
# Skew:                          -1.730   Prob(JB):                         0.00
# Kurtosis:                      25.316   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    0.273319
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sh.601899   R-squared (uncentered):                   0.380
# Model:                            OLS   Adj. R-squared (uncentered):              0.379
# Method:                 Least Squares   F-statistic:                              299.6
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):                    1.05e-52
# Time:                        19:16:57   Log-Likelihood:                          1181.9
# No. Observations:                 490   AIC:                                     -2362.
# Df Residuals:                     489   BIC:                                     -2358.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sse180         0.8768      0.051     17.309      0.000       0.777       0.976
# ==============================================================================
# Omnibus:                      239.930   Durbin-Watson:                   1.733
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2352.319
# Skew:                           1.890   Prob(JB):                         0.00
# Kurtosis:                      13.047   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# sse180    0.876797
# dtype: float64

# %% [markdown]
# #### Save all the beta and R-Squares for all the 30 invidual stocks in one excel and sort them from smallest to the biggest based on Betas

# %%
import pandas as pd
stexcel=pd.read_excel('single_stock.xlsx')
stexcel.sort_values(by='Beta',inplace=True,ascending=True)
print(stexcel)
# Out:
#      Unnamed: 0    Beta  R-Square
# 28    sh.601877  0.2733     0.047
# 21    sh.600598  0.3150     0.147
# 9     sh.600066  0.5460     0.301
# 22    sh.600600  0.8172     0.459
# 6     sh.600036  0.8390     0.510
# 20    sh.600547  0.8694     0.315
# 29    sh.601899  0.8768     0.380
# 4     sh.600028  0.8956     0.510
# 18    sh.601933  0.9152     0.211
# 2     sh.600295  0.9265     0.395
# 16  sh.600295.1  0.9265     0.395
# 15    sh.600196  0.9369     0.335
# 19    sh.600536  0.9770     0.145
# 11    sh.600085  1.0081     0.485
# 0     sh.600009  1.0127     0.474
# 23    sh.600690  1.0180     0.267
# 25    sh.600887  1.0459     0.271
# 27    sh.601006  1.0483     0.532
# 12    sh.600111  1.0636     0.387
# 13    sh.601628  1.0636     0.512
# 1     sh.600010  1.0683     0.259
# 17    sh.600406  1.1320     0.433
# 26    sh.600895  1.1537     0.342
# 3     sh.600019  1.1679     0.579
# 8     sh.600050  1.1808     0.546
# 5     sh.600031  1.2142     0.566
# 10    sh.600068  1.2252     0.518
# 24    sh.600875  1.2709     0.507
# 7     sh.600048  1.2844     0.492
# 14    sh.600150  1.2855     0.401

# %%
stexcel.to_csv('individual_beta.csv')

# %% [markdown]
# ## Step 2

# %% [markdown]
# #### Group all the 30 individual stocks into five groups , each group has five individual stocks

# %% [markdown]
# #### Now we start to use the second period data from 2015-10-08 to 2017-10-08 to caculate the betas for those five groups

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('second_group1.xlsx',sheet_name = 'sheet1')
df['first_group'] = df[['sh.601877','sh.600598','sh.600066','sh.600600','sh.600036','sh.600547']].mean(axis=1)
print (df['first_group'])
df.to_excel('second_group1.xlsx',sheet_name = 'sheet1')
# Out:
# 0      0.026767
# 1      0.019577
# 2      0.025885
# 3      0.004247
# 4     -0.013720
#          ...
# 485   -0.002782
# 486    0.003098
# 487    0.000369
# 488    0.003842
# 489    0.021641
# Name: first_group, Length: 490, dtype: float64

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
df = pd.read_excel('second_group1.xlsx',sheet_name = 'sheet1')
X = df['sse180']
y = df['first_group']
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            first_group   R-squared:                       0.660
# Model:                            OLS   Adj. R-squared:                  0.660
# Method:                 Least Squares   F-statistic:                     949.1
# Date:                Sun, 22 Nov 2020   Prob (F-statistic):          1.57e-116
# Time:                        11:38:21   Log-Likelihood:                 1724.3
# No. Observations:                 490   AIC:                            -3445.
# Df Residuals:                     488   BIC:                            -3436.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0001      0.000      0.309      0.757      -0.001       0.001
# sse180         0.8589      0.028     30.807      0.000       0.804       0.914
# ==============================================================================
# Omnibus:                       29.557   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.666
# Skew:                           0.307   Prob(JB):                     2.03e-15
# Kurtosis:                       4.714   Cond. No.                         85.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from regression import Regression
reg = Regression()
print(reg)
# Out:
# You created an instance of Stats
# <regression.Regression object at 0x0000025AEBDF9250>

# %%
import pandas as pd  
import copy
from stats import *    
  
class Regression:  
    def __init__(self):  
        self.stats = stats()  
          
    def OLS(self, reg_name, data, y_name, beta_names, 
            min_val = 0,  
                max_val = None, constant = True):  
        self.min_val = min_val  
        if max_val != None:  
            self.max_val = max_val  
        else:  
            self.max_val = len(data)  
        self.reg_name = reg_name  
        self.y_name = y_name  
        self.beta_names = copy.copy(beta_names)
        self.data = data.copy()  
        if constant:  
            self.add_constant()  
  
    def add_constant(self):  
        self.data["Constant"] = 1  
        self.beta_names.append("Constant")

# %%
import pandas as pd
from regression import Regression

# %%
reg = Regression()
print(reg)
# Out:
# You created an instance of Stats
# <regression.Regression object at 0x0000025AEBED9D30>

# %%
reg

# %%
# Selecting Variables
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
data = pd.read_excel('second_group1.xlsx',sheet_name = 'sheet1')
y_var = ['first_group']
x_var = ['sse180']
reg.OLS(reg_name = "Pork", data = data, y_name = y_var, beta_names = x_var)
# reg.data

# %%
#regression.py
# . . . 
def calculate_regression_stats(self):
    self.sum_square_stats()
    self.calculate_degrees_of_freedom()
    self.calculate_estimator_variance()
    self.calculate_covariance_matrix()

def calculate_degrees_of_freedom(self):  
    # Degrees of freedom compares the number of observations to the number  
    # of exogenous variables used to form the prediction  
    self.lost_degrees_of_freedom = len(self.estimates)  
    self.num_obs = self.max_val + 1 - self.min_val  
    self.degrees_of_freedom = self.num_obs - self.lost_degrees_of_freedom  
         
def calculate_estimator_variance(self):  
    # estimator variance is the sse normalized by the degrees of freedom  
    # thus, estimator variance increases as the number of exogenous  
    # variables used in estimation increases(i.e., as degrees of freedom   
    # fall)  
    self.estimator_variance = self.sse / self.degrees_of_freedom  

def calculate_covariance_matrix(self):  
    # Covariance matrix will be used to estimate standard errors for  
    # each coefficient.  
    # estimator variance * (X'X)**-1  
    self.cov_matrix = float(self.estimator_variance) * self.X_transp_X_inv  
    self.cov_matrix = pd.DataFrame(self.cov_matrix,  
                                   columns = self.beta_names,  
                                   index = self.beta_names)

# %%
reg = Regression()
reg.OLS("group1", data, y_var, x_var)
# Out:
# You created an instance of Stats

# %%
reg.ssr, reg.sse, reg.sst

reg.stats_DF
# Out:
#            Estimation Statistics
# r**2                    0.660421
# Adj. r**2               0.659726
# f-stat                951.017473
# Est Var                 0.000052
# MSE                     0.007178
# SSE                     0.025192
# SSR                     0.048994
# SST                     0.074185
# Obs.                  491.000000
# DOF                   489.000000

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('second_group2.xlsx',sheet_name = 'sheet1')
df['second_group'] = df[['sh.601899','sh.600028','sh.601933','sh.600295','sh.600295.1','sh.600196']].mean(axis=1)
print (df['second_group'])
df.to_excel('second_group2.xlsx',sheet_name = 'sheet1')
# Out:
# 0      0.043679
# 1      0.020129
# 2      0.024684
# 3      0.011026
# 4     -0.015453
#          ...
# 485    0.002025
# 486    0.008696
# 487   -0.005962
# 488    0.004491
# 489    0.011636
# Name: second_group, Length: 490, dtype: float64

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
df = pd.read_excel('second_group2.xlsx',sheet_name = 'sheet1')
X = df['sse180']
y = df['second_group']
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           second_group   R-squared:                       0.479
# Model:                            OLS   Adj. R-squared:                  0.478
# Method:                 Least Squares   F-statistic:                     447.9
# Date:                Sun, 22 Nov 2020   Prob (F-statistic):           5.14e-71
# Time:                        11:39:10   Log-Likelihood:                 1483.3
# No. Observations:                 490   AIC:                            -2963.
# Df Residuals:                     488   BIC:                            -2954.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0006      0.001      1.170      0.243      -0.000       0.002
# sse180         0.9649      0.046     21.164      0.000       0.875       1.054
# ==============================================================================
# Omnibus:                       99.769   Durbin-Watson:                   1.903
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1105.686
# Skew:                          -0.504   Prob(JB):                    8.00e-241
# Kurtosis:                      10.290   Cond. No.                         85.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Selecting Variables
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
data = pd.read_excel('second_group2.xlsx',sheet_name = 'sheet1')
y_var = ['second_group']
x_var = ['sse180']
reg.OLS(reg_name = "Pork", data = data, y_name = y_var, beta_names = x_var)
# reg.data

# %%
reg = Regression()
reg.OLS("group2", data, y_var, x_var)
# Out:
# You created an instance of Stats

# %%
reg.ssr, reg.sse, reg.sst

reg.stats_DF
# Out:
#            Estimation Statistics
# r**2                    0.478578
# Adj. r**2               0.477511
# f-stat                448.819398
# Est Var                 0.000138
# MSE                     0.011737
# SSE                     0.067368
# SSR                     0.061833
# SST                     0.129201
# Obs.                  491.000000
# DOF                   489.000000

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('second_group3.xlsx',sheet_name = 'sheet1')
df['third_group'] = df[['sh.600536','sh.600085','sh.600009','sh.600690','sh.600887','sh.601006']].mean(axis=1)
print (df['third_group'])
df.to_excel('second_group3.xlsx',sheet_name = 'sheet1')
# Out:
# 0      0.038212
# 1      0.003433
# 2      0.025620
# 3      0.012399
# 4     -0.013894
#          ...
# 485   -0.002833
# 486    0.000025
# 487    0.007617
# 488    0.007885
# 489    0.013622
# Name: third_group, Length: 490, dtype: float64

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
df = pd.read_excel('second_group3.xlsx',sheet_name = 'sheet1')
X = df['sse180']
y = df['third_group']
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            third_group   R-squared:                       0.681
# Model:                            OLS   Adj. R-squared:                  0.680
# Method:                 Least Squares   F-statistic:                     1041.
# Date:                Sun, 22 Nov 2020   Prob (F-statistic):          4.29e-123
# Time:                        11:50:04   Log-Likelihood:                 1692.2
# No. Observations:                 490   AIC:                            -3380.
# Df Residuals:                     488   BIC:                            -3372.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.000      0.794      0.427      -0.000       0.001
# sse180         0.9602      0.030     32.262      0.000       0.902       1.019
# ==============================================================================
# Omnibus:                       22.191   Durbin-Watson:                   1.906
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.835
# Skew:                           0.228   Prob(JB):                     6.76e-11
# Kurtosis:                       4.444   Cond. No.                         85.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Selecting Variables
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
data = pd.read_excel('second_group3.xlsx',sheet_name = 'sheet1')
y_var = ['third_group']
x_var = ['sse180']
reg.OLS(reg_name = "group3", data = data, y_name = y_var, beta_names = x_var)
# reg.data

# %%
reg = Regression()
reg.OLS("group3", data, y_var, x_var)
# Out:
# You created an instance of Stats

# %%
reg.ssr, reg.sse, reg.sst
reg.stats_DF
# Out:
#            Estimation Statistics
# r**2                    0.680799
# Adj. r**2               0.680146
# f-stat               1042.949195
# Est Var                 0.000059
# MSE                     0.007662
# SSE                     0.028711
# SSR                     0.061235
# SST                     0.089945
# Obs.                  491.000000
# DOF                   489.000000

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('second_group4.xlsx',sheet_name = 'sheet1')
df['fourth_group'] = df[['sh.600111','sh.601628','sh.600010','sh.600406','sh.600895','sh.600019']].mean(axis=1)
print (df['fourth_group'])
df.to_excel('second_group4.xlsx',sheet_name = 'sheet1')
# Out:
# 0      0.033897
# 1      0.024980
# 2      0.030713
# 3      0.009751
# 4      0.009894
#          ...
# 485    0.005566
# 486    0.004957
# 487   -0.006501
# 488    0.002844
# 489    0.004997
# Name: fourth_group, Length: 490, dtype: float64

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
df = pd.read_excel('second_group4.xlsx',sheet_name = 'sheet1')
X = df['sse180']
y = df['fourth_group']
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           fourth_group   R-squared:                       0.730
# Model:                            OLS   Adj. R-squared:                  0.730
# Method:                 Least Squares   F-statistic:                     1322.
# Date:                Sun, 22 Nov 2020   Prob (F-statistic):          5.66e-141
# Time:                        12:00:44   Log-Likelihood:                 1620.9
# No. Observations:                 490   AIC:                            -3238.
# Df Residuals:                     488   BIC:                            -3229.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -8.89e-05      0.000     -0.222      0.825      -0.001       0.001
# sse180         1.2516      0.034     36.353      0.000       1.184       1.319
# ==============================================================================
# Omnibus:                       56.348   Durbin-Watson:                   2.088
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              405.975
# Skew:                          -0.031   Prob(JB):                     6.98e-89
# Kurtosis:                       7.459   Cond. No.                         85.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Selecting Variables
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
data = pd.read_excel('second_group4.xlsx',sheet_name = 'sheet1')
y_var = ['fourth_group']
x_var = ['sse180']
reg.OLS(reg_name = "group4", data = data, y_name = y_var, beta_names = x_var)
# reg.data

# %%
reg = Regression()
reg.OLS("group4", data, y_var, x_var)
# Out:
# You created an instance of Stats

# %%
reg.ssr, reg.sse, reg.sst
reg.stats_DF
# Out:
#            Estimation Statistics
# r**2                    0.730319
# Adj. r**2               0.729767
# f-stat               1324.252636
# Est Var                 0.000079
# MSE                     0.008863
# SSE                     0.038415
# SSR                     0.104032
# SST                     0.142447
# Obs.                  491.000000
# DOF                   489.000000

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('second_group5.xlsx',sheet_name = 'sheet1')
df['fifth_group'] = df[['sh.600050','sh.600031','sh.600068','sh.600875','sh.600048','sh.600150']].mean(axis=1)
print (df['fifth_group'])
df.to_excel('second_group5.xlsx',sheet_name = 'sheet1')
# Out:
# 0      0.037827
# 1      0.010240
# 2      0.039124
# 3      0.005196
# 4     -0.021570
#          ...
# 485    0.010097
# 486    0.007864
# 487   -0.009318
# 488    0.002932
# 489    0.006016
# Name: fifth_group, Length: 490, dtype: float64

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
df = pd.read_excel('second_group5.xlsx',sheet_name = 'sheet1')
X = df['sse180']
y = df['fifth_group']
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            fifth_group   R-squared:                       0.783
# Model:                            OLS   Adj. R-squared:                  0.783
# Method:                 Least Squares   F-statistic:                     1761.
# Date:                Sun, 22 Nov 2020   Prob (F-statistic):          4.81e-164
# Time:                        12:10:31   Log-Likelihood:                 1677.9
# No. Observations:                 490   AIC:                            -3352.
# Df Residuals:                     488   BIC:                            -3343.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -8.993e-05      0.000     -0.252      0.801      -0.001       0.001
# sse180         1.2862      0.031     41.969      0.000       1.226       1.346
# ==============================================================================
# Omnibus:                       11.536   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               21.219
# Skew:                           0.036   Prob(JB):                     2.47e-05
# Kurtosis:                       4.017   Cond. No.                         85.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Selecting Variables
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
data = pd.read_excel('second_group5.xlsx',sheet_name = 'sheet1')
y_var = ['fifth_group']
x_var = ['sse180']
reg.OLS(reg_name = "group5", data = data, y_name = y_var, beta_names = x_var)
# reg.data

# %%
reg = Regression()
reg.OLS("group5", data, y_var, x_var)
# Out:
# You created an instance of Stats

# %%
reg.ssr, reg.sse, reg.sst
reg.stats_DF
# Out:
#            Estimation Statistics
# r**2                    0.783050
# Adj. r**2               0.782606
# f-stat               1764.970828
# Est Var                 0.000062
# MSE                     0.007890
# SSE                     0.030438
# SSR                     0.109861
# SST                     0.140299
# Obs.                  491.000000
# DOF                   489.000000

# %% [markdown]
# ## Step 3

# %% [markdown]
# #### Cross sectional analysis: analyze whether there is positive correlation between system risk and market risk as expected by CAPM.
# Use the data of third period from 2017-10-08 to 2019-10-08 and the betas obtained from step 2, regress between portofolio average daily stock return and group betas.
#
# Regression equation is as below:
#
#                                      R_pi=γ_0+γ_1β_pi+ε_i              (4)
#
# In equation (4), R_pi is the daily average return from Oct 8th, 2017 to Oct 8th, 2019, γ_0 and γ_1 are the coefficients which need to be estimated, ε_i is residual error

# %% [markdown]
# #### Caculate the average stock return for those six portfolios

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('third period.xlsx',sheet_name = 'sheet1')
df['fifth_group'] = df[['sh.600050','sh.600031','sh.600068','sh.600875','sh.600048','sh.600150']].mean(axis=1)
print (df['fifth_group'])
df.to_excel('third period.xlsx',sheet_name = 'sheet1')
# Out:
# 0      0.006016
# 1     -0.003769
# 2      0.001148
# 3     -0.001366
# 4      0.001983
#          ...
# 542    0.005177
# 543    0.010596
# 544   -0.005168
# 545    0.013988
# 546    0.011936
# Name: fifth_group, Length: 547, dtype: float64

# %%
df['fifth_group'].mean()
# Out:
# 0.0002685971593540509

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('third period.xlsx',sheet_name = 'sheet1')
df['fourth_group'] = df[['sh.600111','sh.601628','sh.600010','sh.600406','sh.600895','sh.600019']].sum(axis=1)
print (df['fourth_group'])
df.to_excel('third period.xlsx',sheet_name = 'sheet1')
# Out:
# 0      0.029982
# 1     -0.068965
# 2     -0.006042
# 3      0.014196
# 4      0.014403
#          ...
# 542    0.006412
# 543    0.047015
# 544    0.034586
# 545    0.065130
# 546   -0.015033
# Name: fourth_group, Length: 547, dtype: float64

# %%
df['fourth_group'].mean()
# Out:
# -0.0007593720932358381

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('third period.xlsx',sheet_name = 'sheet1')
df['third_group'] = df[['sh.600536','sh.600085','sh.600009','sh.600690','sh.600887','sh.601006']].sum(axis=1)
print (df['third_group'])
df.to_excel('third_group.xlsx',sheet_name = 'sheet1')
# Out:
# 0      0.081730
# 1      0.003356
# 2      0.043896
# 3      0.096953
# 4     -0.028782
#          ...
# 542    0.029634
# 543    0.086903
# 544   -0.062975
# 545    0.026362
# 546    0.034653
# Name: third_group, Length: 547, dtype: float64

# %%
df['third_group'].mean()
# Out:
# 0.00523864822486287

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('third period.xlsx',sheet_name = 'sheet1')
df['second_group'] = df[['sh.601899','sh.600028','sh.601933','sh.600295','sh.600295.1','sh.600196']].mean(axis=1)
print (df['second_group'])
df.to_excel('third period.xlsx',sheet_name = 'sheet1')
# Out:
# 0      0.011636
# 1     -0.005915
# 2      0.000462
# 3      0.005234
# 4      0.002308
#          ...
# 542   -0.003328
# 543    0.007330
# 544    0.008808
# 545    0.005982
# 546    0.009849
# Name: second_group, Length: 547, dtype: float64

# %%
df['second_group'].mean()
# Out:
# -0.0002288640755636832

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('third period.xlsx',sheet_name = 'sheet1')
df['first_group'] = df[['sh.601877','sh.600598','sh.600066','sh.600600','sh.600036','sh.600547']].sum(axis=1)
print (df['first_group'])
df.to_excel('first_group1.xlsx',sheet_name = 'sheet1')
# Out:
# 0      0.129848
# 1      0.034419
# 2     -0.033634
# 3      0.071054
# 4      0.058021
#          ...
# 542   -0.014201
# 543    0.032113
# 544   -0.003595
# 545    0.055005
# 546    0.014083
# Name: first_group, Length: 547, dtype: float64

# %%
df['first_group'].mean()
# Out:
# 0.0017445407312614125

# %% [markdown]
# #### Run the regression between the five average stock returns and the betas obtained from the step 2

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
df = pd.read_excel('group beta and average return .xlsx',sheet_name = 'sheet1')
X = df['group_beta']
y = df['average_return']
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         average_return   R-squared:                       0.230
# Model:                            OLS   Adj. R-squared:                 -0.027
# Method:                 Least Squares   F-statistic:                    0.8957
# Date:                Sun, 22 Nov 2020   Prob (F-statistic):              0.414
# Time:                        20:27:39   Log-Likelihood:                 24.496
# No. Observations:                   5   AIC:                            -44.99
# Df Residuals:                       3   BIC:                            -45.77
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0075      0.007      1.145      0.335      -0.013       0.028
# group_beta    -0.0057      0.006     -0.946      0.414      -0.025       0.014
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.795
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.583
# Skew:                           0.809   Prob(JB):                        0.747
# Kurtosis:                       2.575   Cond. No.                         12.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\Shane\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
data = pd.read_excel('group beta and average return .xlsx',sheet_name = 'sheet1')
y_var = ['average_return']
x_var = ['group_beta']
reg.OLS(reg_name = 'average_return', data = data, y_name = y_var, beta_names = x_var)
# reg.data

# %%
reg = Regression()
# . . .
reg.OLS('average_return', data, y_var, x_var)
# Out:
# You created an instance of Stats

# %%
reg.estimates
# Out:
#                     Coefficient        SE    t-stat  p-value signficance
# y = average_return
# group_beta            -0.005742  0.005255 -1.092825   0.3243
# Constant               0.007491  0.005665  1.322364   0.2433

# %% [markdown]
# #### Finally we add the non-system risk to the regression equationSexual to further analyze whether the individual stock is compensated by the market with regards to the nonsystem risk.

# %% [markdown]
#                          R_pi=γ_0+γ_1 β_pi+γ_2 σ_pi+ε_i           (5)
#
# 𝜎𝑝𝑖 is the residual obtained from step 2.

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
data = pd.read_excel('group beta and average return .xlsx',sheet_name = 'sheet1')
y_var = ['average_return']
x_vars = ['group_beta','r']
reg.OLS(reg_name = 'average_return', data = data, y_name = y_var, beta_names = x_vars)
# reg.data

# %%
reg = Regression()
# . . .
reg.OLS('average_return', data, y_var, x_vars)
# Out:
# You created an instance of Stats

# %%
reg.estimates
# Out:
#                     Coefficient        SE    t-stat  p-value signficance
# y = average_return
# group_beta             0.053613  0.155939  0.343804  0.74831
# r                     -0.411115  1.079313 -0.380904  0.72264
# Constant              -0.023950  0.082789 -0.289282  0.78674

# %% [markdown]
# #### Adding the quadratic variable and obtain another estimation regression:

# %% [markdown]
#                    R_pi=γ_0+γ_1 β_pi+γ_2 σ_pi+γ_3 β_pi^2+ε_i      (6)

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
df = pd.read_excel('group beta and average return .xlsx',sheet_name = 'sheet1')
X = df['group_beta']
y = df['average_return','r']
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
print(est.summary())
