# %% [markdown]
# # The empirical analysis of CAPM in A share of real estate company in Shenzhen, China

# %% [markdown]
# ## Overview of CAPM theoretical framework
#
# CPM model was built on the earlier work on diversification and modern portfolio theory, which was later improved by Sharpe, Markowitz and Merton Miller. The CAPM developed in the 1960s was a true revolution in financial theory, due to their contribution, William F. Sharpe received the Nobel prize in Economic Sciences in 1990 This Model basically is for estimating the capital assets using a linear equilibrium model of returns on investments that explains returns above risk-free rate using covariance with the overall market. (Džaja & Aljinović,2013). In market equilibrium the CAPM expresses the relationship between an asset’s expected return and so-called systematic risk beta in a liner function. (Sharpe, Litner, Mossin, 1966).. CAPM predicts that the expected return on an asset equals the risk-free rate plus a risk premium, it is linearly related to systematic risk measured by the assets’ beta. (Basu and Chawla, 2010). Due to the simplicity and rationality of CAPM, CAPM still remains very popular in many situations.
#
# In the development of the asset pricing model, the assumptions of the models are( Džaja Aljinović,2013)( Basu& Chawla,2008)( Blac ,Jensen& Scholes,1972)
#
# 1)Investors are risk averse and willing to maximize their expected rate of return over a period
#
# 2)Investors prefer a portfolio with higher returns
#
# 3)Free to lend and borrow with a risk-free interest
#
# 4)The property is indefinitely divisible
#
# 5)Trade without transaction or taxation costs.

# %% [markdown]
# ## Methodology
#
# In empirical analysis, this model is expressed:
#
#                                      R_p=R_f+β_p (R_m-R_f )+ε_p   (1)
#
# Where R_p  is the expected return of individual or portfolio stock in real estate industry, 𝑅𝑓 is a risk-free interest rate, 𝑅𝑚 represents the expected return of a market portfolio, 𝛽𝑝 measures the systematic risk of individual stock or market portfolio and 𝜀𝑝 is the stochastic error term. In this paper, CAPM is used to analyze the Shanghai property stock market and test whether the effectiveness of this model is verified.
#
# This paper is to use time series regression based on CAPM model to make estimation about the individual and portfolio β, which will be useful to understand the risk about Shanghai real estate market; cross sectional regression-based method developed by Black, Jensen and Scholes (1972) is to verify the relationship between risk and expected return.
#
# The detailed steps are: First, separate the whole time range from May 1st, 2010 to May 1st, 2019 into three periods; Second: Use the data in the first period to calculate the beta for individual stock; Third, rank the individual beta of each stock from lowest to highest, and make different portfolios; Fourth: use the data of second term to estimate the portfolio beta; fifth, make the cross sectional regression using the third period data coupled with these portfolio betas to determine the relationships between expected return and risk. (Tao Zhao, 2001) (Wang and Geng, 2012) (Zhu, 2010)

# %% [markdown]
# ## Data
# The data is collected from BaoStock, this is a free, open source securities data platform providing a large number of accurate, complete securities historical, financial data of public companies. Data information is obtained through python to meet the data requirements for econometric research.
# There are total 51 stocks from the Stock pool of Shenzhen A share about real estate companies from November, 2010 to November,2019, daily, of  which three companies are extremely short of relevant data, that is why these three samples are deleted. The three companies are Dongfeng Sci-Tech Group (sz000160), Guangdong Jadiete Hldgs(sz 000168) and China Merchants Shekou Industrial Zone Holdings (sz001979) respectively.
#
# Here, Shenzhen Stock Exchange is regarded as the market portfolio and the return on stock of SZCI as the return of market portfolio. The Chinese researchers normally will either do the split-adjusted share prices about the data in stock markets (Wang& Geng, 2012), or reverse split-adjusted share prices (Liao& Wang, 2003) (Zhao, 2013). In this paper, all the data are collected using the reverse split-adjusted share prices, this is to consider the influence of dividend, allotment and stock segmentation on the data (Zhao, 2013).
#
# Regarding the return on every stock, there are two methods of calculation, one is logarithmic algorithm, using this way( Sakouvogui and Nganje, 2019), the data processed is approximately normal distribution, which is useful to improve the stability of time series; another is to subtract the closing price of the specific stock at the ending term and the initial closing price and then divide by the beginning closing price. (Zhao, 2013) (Wang & Geng 2012)
#
# Here, in order to ensure the stability of time series, percentage change is used to calculate the daily return about stocks.
#
#                                    R_it= [(P_it) - P_(i(t-1))]/[P_i(t-1)] (2)
#
# Where, 𝑃𝑖𝑡 is the closing price of stock i at moment t, 𝑃𝑖(𝑡−1) is the closing price at moment t-1.

# %% [markdown]
# # Estimation for individual stock
# Rewrite the equation (1) into (3), Use Single Index Model estimation:
#
#                             R_it−R_f=α_i+β_i(R_mt−R_f) +ε_it (3)
#
# Where R_it is the daily return of stock i at time t; R_mt is the return of market portfolio; R_f is the return of the risk-free asset, here R_f equates 0.009027% (one-year deposit rate on bank of China/360) as Chinese researchers basically regard the deposit rate as risk free asset by default. (Liao and Shen, 2004).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot
series = pd.read_csv ('housing price of Shenzhen.csv',index_col = "Year", parse_dates = True)
fig = series.plot(title="20 year's housing price trend in Shenzhen, China (CNY/Square Meters) ").get_figure()
fig.savefig("figure.png")

# %% [markdown]
# ### Statistics: plotting two time series data of RESI ( real estate stocks ) and SECI (Shenzhen Stock Exchange)

# %%
series = pd.read_csv ('Data for RESI and SECI.csv',index_col = "Year", parse_dates = True)
# series.plot()
# pyplot.show()
# pyplot.close()

# plt.figure(figsize=(20,10))
# plt.title("Closing Price of SZ Stock Exchange and Real Estate Sector")
fig = series.plot(title="Closing Price of SZ Stock Exchange and Real Estate Sector").get_figure()

# plt.show()
# plt.close()
fig.savefig("figure1.png")

# %%
import pandas as pd
import matplotlib.pyplot as plt 
df = pd.read_csv ("Data for RESI and SECI.csv") 
# x axis values 
x = df['RESI']
# corresponding y axis values 
y = df["SECI"] 
  
# plotting the points  
plt.plot(x, y) 
  
# naming the x axis 
plt.xlabel('RESI') 
# naming the y axis 
plt.ylabel('SECI') 
  
# giving a title to my graph 
plt.title('Scatter plotting between RESI and SECI') 
plt.savefig('fig2.png', dpi=300, bbox_inches='tight')
plt.show()
# function to show the plot 
plt.close()

# %%
import pandas as pd
df = pd.read_csv ('final .csv') 
print(df.shape)     # read the row 
print(df.columns)   # read the columns 
print(df.head(3))   # print the first row 
print(df.tail(3))   # print the last row to check the missing variables
# Out:
# (2192, 52)
# Index(['Unnamed: 0', 'date', 'seci', 'sz.000002', 'sz.000006', 'sz.000007',
#        'sz.000011', 'sz.000014', 'sz.000031', 'sz.000036', 'sz.000042',
#        'sz.000043', 'sz.000046', 'sz.000069', 'sz.000402', 'sz.000502',
#        'sz.000514', 'sz.000517', 'sz.000537', 'sz.000540', 'sz.000558',
#        'sz.000560', 'sz.000573', 'sz.000608', 'sz.000615', 'sz.000616',
#        'sz.000620', 'sz.000631', 'sz.000656', 'sz.000667', 'sz.000668',
#        'sz.000671', 'sz.000691', 'sz.000718', 'sz.000732', 'sz.000736',
#        'sz.000797', 'sz.000838', 'sz.000897', 'sz.000909', 'sz.000926',
#        'sz.000961', 'sz.000965', 'sz.002016', 'sz.002077', 'sz.002133',
#        'sz.002146', 'sz.002147', 'sz.002208', 'sz.002244', 'sz.002285',
#        'sz.002377'],
#       dtype='object')
#    Unnamed: 0        date     seci   sz.000002   sz.000006  sz.000007  \
# 0           1  2010-11-01  1341.84  786.354369  125.570515  34.336499
# 1           2  2010-11-02  1333.29  787.170089  125.570515  33.969046
# 2           3  2010-11-03  1309.41  802.668775  126.251114  34.254843
#
#    sz.000011  sz.000014  sz.000031  sz.000036  ...  sz.000965  sz.002016  \
# 0  27.632105  78.010710  74.924088  28.347629  ...  20.965871  28.806830
# 1  27.695994  78.360220  75.234547  28.044121  ...  21.031905  29.159927
# 2  28.302942  76.962179  74.924088  27.679911  ...  20.899837  30.484041
#
#    sz.002077  sz.002133  sz.002146  sz.002147  sz.002208  sz.002244  \
# 0  16.032696  15.484399  43.140410  37.272224  37.702783  31.818213
# 1  15.387950  15.381032  43.465998  36.659194  38.009559  33.082512
# 2  15.173034  14.843523  42.000852  35.335049  37.610750  32.424023
#
#    sz.002285  sz.002377
# 0  59.012836      21.59
# 1  58.585207      20.71
# 2  58.054947      20.46
#
# [3 rows x 52 columns]
#       Unnamed: 0        date      seci    sz.000002   sz.000006  sz.000007  \
# 2189        2190  2019-10-30  1628.616  2939.110227  203.971985  60.818932
# 2190        2191  2019-10-31  1616.189  2925.875960  204.362736  60.548325
# 2191        2192  2019-11-01  1637.002  2958.961628  209.442498  60.615977
#
#       sz.000011  sz.000014  sz.000031  sz.000036  ...  sz.000965  sz.002016  \
# 2189  35.805891  68.968774  81.020513  39.656534  ...   8.946758  44.402473
# 2190  34.437513  67.825645  84.658168  38.315492  ...   8.777418  41.982316
# 2191  35.083692  69.349817  80.359121  38.794436  ...   8.890311  43.957954
#
#       sz.002077  sz.002133  sz.002146  sz.002147  sz.002208  sz.002244  \
# 2189   7.907427   9.664740  93.598611   6.260907  33.654265  24.511782
# 2190   7.642866   9.518747  92.745776   6.192106  33.388013  24.684806
# 2191   7.701658   9.635541  94.238237   6.123305  33.388013  24.973180
#
#       sz.002285  sz.002377
# 2189  51.189180  16.155369
# 2190  50.897504  16.197114
# 2191  51.043342  16.698056
#
# [3 rows x 52 columns]

# %% [markdown]
# ### Manipulating the data so that it could be used for later analysis.

# %% [markdown]
# #### Split the data into three periods and save as csv
# #### First Period from 2013-10-08 to 2015-10-08

# %%
# df[(df['date']>='20131008')(df['date']<='20151008')]
mask = (df['date'] > '2010-10-31') & (df['date'] <='2013-10-31' )
# mask = (df['date'] > '10-08-2013') & (df['date'] <='10-08-2015' )
df = df.loc[mask]
df.loc[mask].to_csv('final_first period')
df
# Out:
#      Unnamed: 0        date     seci   sz.000002   sz.000006  sz.000007  \
# 0             1  2010-11-01  1341.84  786.354369  125.570515  34.336499
# 1             2  2010-11-02  1333.29  787.170089  125.570515  33.969046
# 2             3  2010-11-03  1309.41  802.668775  126.251114  34.254843
# 3             4  2010-11-04  1335.66  795.327292  126.251114  35.969627
# 4             5  2010-11-05  1352.12  794.511572  129.313810  36.908675
# ..          ...         ...      ...         ...         ...        ...
# 722         723  2013-10-25  1039.94  758.007046  145.680021  62.467115
# 723         724  2013-10-28  1037.85  743.528260  146.305257  60.548191
# 724         725  2013-10-29  1019.04  753.748579  140.365513  59.200861
# 725         726  2013-10-30  1035.20  773.337525  143.179076  59.976596
# 726         727  2013-10-31  1021.04  784.409538  148.806201  59.731627
#
#      sz.000011  sz.000014  sz.000031  sz.000036  ...  sz.000965  sz.002016  \
# 0    27.632105  78.010710  74.924088  28.347629  ...  20.965871  28.806830
# 1    27.695994  78.360220  75.234547  28.044121  ...  21.031905  29.159927
# 2    28.302942  76.962179  74.924088  27.679911  ...  20.899837  30.484041
# 3    28.239053  77.101983  75.441520  28.226225  ...  20.685226  31.455058
# 4    27.983496  78.430123  77.511246  28.711838  ...  20.916346  32.455499
# ..         ...        ...        ...        ...  ...        ...        ...
# 722  25.875150  73.332750  39.004871  19.849410  ...  13.496211  31.240489
# 723  26.002929  73.896848  39.110289  19.849410  ...  13.197952  31.699908
# 724  24.916811  68.467404  38.477778  17.846259  ...  12.974258  29.903998
# 725  25.268202  71.287895  39.004871  17.785557  ...  13.769615  29.987528
# 726  25.555704  74.531459  39.215708  18.028363  ...  13.073677  30.530478
#
#      sz.002077  sz.002133  sz.002146  sz.002147  sz.002208  sz.002244  \
# 0    16.032696  15.484399  43.140410  37.272224  37.702783  31.818213
# 1    15.387950  15.381032  43.465998  36.659194  38.009559  33.082512
# 2    15.173034  14.843523  42.000852  35.335049  37.610750  32.424023
# 3    15.817781  14.926216  41.805499  35.800952  37.702783  32.792777
# 4    15.645848  15.050257  43.238086  36.389461  38.377690  32.450363
# ..         ...        ...        ...        ...        ...        ...
# 722   9.074962  10.531066  52.490258  14.287304  18.209401  22.488930
# 723   8.784564  10.346311  50.923384  14.672753  18.400076  22.488930
# 724   8.450605  10.082374  49.400035  15.238078  17.828053  21.276952
# 725   8.595804  10.214343  48.790695  15.417954  18.082285  21.330817
# 726   8.595804  10.267130  50.923384  14.672753  18.304739  21.384683
#
#      sz.002285  sz.002377
# 0    59.012836  21.590000
# 1    58.585207  20.710000
# 2    58.054947  20.460000
# 3    57.541792  21.160000
# 4    57.798369  20.865838
# ..         ...        ...
# 722  46.501558  14.363642
# 723  46.780637  13.917314
# 724  45.838745  14.018752
# 725  48.315573  14.546231
# 726  47.443450  14.688244
#
# [727 rows x 52 columns]

# %% [markdown]
# #### Second Period from 2015-10-08 to 2017-10-08

# %%
# df[(df['date']>='20131008')(df['date']<='20151008')]
import pandas as pd
df = pd.read_csv ('final .csv') 
mask = (df['date'] > '2013-10-31') & (df['date'] <='2016-10-31' )
# mask = (df['date'] > '10-08-2013') & (df['date'] <='10-08-2015' )
df = df.loc[mask]
df.loc[mask].to_csv('final_second period')
df
# Out:
#       Unnamed: 0        date      seci    sz.000002   sz.000006   sz.000007  \
# 727          728  2013-11-01  1016.970   799.740018  145.367403   59.935768
# 728          729  2013-11-04  1021.470   783.557845  146.617875   59.690799
# 729          730  2013-11-05  1034.610   783.557845  150.994528   60.139909
# 730          731  2013-11-06  1023.860   768.227366  153.182854   59.894940
# 731          732  2013-11-07  1011.260   763.968899  158.497362   59.323346
# ...          ...         ...       ...          ...         ...         ...
# 1454        1455  2016-10-25  2077.748  2420.049883  337.559814  105.295876
# 1455        1456  2016-10-26  2069.363  2435.532009  333.592412  105.704158
# 1456        1457  2016-10-27  2068.086  2396.826693  333.592412  106.357409
# 1457        1458  2016-10-28  2052.015  2394.891428  324.665756  106.643206
# 1458        1459  2016-10-31  2050.276  2411.341187  325.326990  105.418361
#
#       sz.000011   sz.000014   sz.000031  sz.000036  ...  sz.000965  sz.002016  \
# 727   25.332092   73.050701   39.215708  17.603452  ...  13.023968  30.112825
# 728   25.555704   72.768652   39.321127  17.542751  ...  13.247662  29.945763
# 729   25.715427   74.390434   39.742801  17.846259  ...  13.869034  29.987528
# 730   25.364036   71.569944   40.164475  17.785557  ...  13.471356  29.569875
# 731   25.332092   73.191726   39.848219  18.392573  ...  13.222807  28.985160
# ...         ...         ...         ...        ...  ...        ...        ...
# 1454  61.388061  157.173003  102.371706  55.481226  ...  17.440159  45.621740
# 1455  60.104922  154.553453  101.088049  55.724032  ...  17.540390  48.901735
# 1456  61.252993  158.801372  100.446220  55.966838  ...  17.465217  49.285111
# 1457  59.564653  155.473835   99.376505  55.420524  ...  17.390044  46.857063
# 1458  61.455594  158.164184   98.413762  55.724032  ...  17.114409  46.729271
#
#       sz.002077  sz.002133  sz.002146  sz.002147  sz.002208  sz.002244  \
# 727    8.566765  10.267130  51.967966  14.390090  18.336518  21.384683
# 728    8.566765  10.267130  51.053957  14.749843  18.400076  21.303884
# 729    8.697444  10.293524  50.444617  14.801236  18.495413  21.088422
# 730    8.595804  10.187949  50.183472  14.904022  18.304739  20.684429
# 731    8.407045  10.082374  50.749287  14.338697  20.147924  20.980690
# ...         ...        ...        ...        ...        ...        ...
# 1454  28.822425  22.714443  71.768740  37.285752  59.949401  37.898290
# 1455  28.366793  24.872453  72.881433  37.157269  59.624471  37.731337
# 1456  27.720089  23.378446  75.106821  37.260055  59.949401  37.675686
# 1457  27.793578  22.354774  74.457749  38.442099  58.714670  37.564384
# 1458  27.822973  22.354774  75.848616  41.191634  57.739883  37.564384
#
#        sz.002285  sz.002377
# 727    47.617875  14.688244
# 728    47.966724  14.688244
# 729    49.466774  14.647669
# 730    48.106263  14.870833
# 731    45.350357  14.363642
# ...          ...        ...
# 1454  119.627254  38.167043
# 1455  120.053987  38.167043
# 1456  119.200522  38.167043
# 1457  114.648712  38.167043
# 1458  113.226272  38.167043
#
# [732 rows x 52 columns]

# %% [markdown]
# #### Third Period from 2017-10-08 to 2019-10-08

# %%
# df[(df['date']>='20131008')(df['date']<='20151008')]
import pandas as pd
df = pd.read_csv ('final .csv') 
mask = (df['date'] > '2016-10-31') & (df['date'] <='2019-11-01' )
# mask = (df['date'] > '10-08-2013') & (df['date'] <='10-08-2015' )
df = df.loc[mask]
df.loc[mask].to_csv('final_third period')
df
# Out:
#       Unnamed: 0        date      seci    sz.000002   sz.000006   sz.000007  \
# 1459        1460  2016-11-01  2073.112  2495.525249  335.245496  106.030783
# 1460        1461  2016-11-02  2060.053  2409.405921  336.898580  105.908299
# 1461        1462  2016-11-03  2071.586  2406.503022  336.237347  109.582835
# 1462        1463  2016-11-04  2067.153  2379.409301  340.865983  110.603540
# 1463        1464  2016-11-07  2066.809  2337.801086  333.923029  113.910622
# ...          ...         ...       ...          ...         ...         ...
# 2187        2188  2019-10-28  1658.241  2964.475907  202.799733   61.427798
# 2188        2189  2019-10-29  1642.682  2941.315939  200.845978   61.224843
# 2189        2190  2019-10-30  1628.616  2939.110227  203.971985   60.818932
# 2190        2191  2019-10-31  1616.189  2925.875960  204.362736   60.548325
# 2191        2192  2019-11-01  1637.002  2958.961628  209.442498   60.615977
#
#       sz.000011   sz.000014  sz.000031  sz.000036  ...  sz.000965  sz.002016  \
# 1459  63.414069  161.350123  99.162562  55.481226  ...  17.114409  47.027452
# 1460  62.569899  159.367761  98.413762  54.692106  ...  16.663370  48.731346
# 1461  61.793262  158.234983  98.841648  54.570702  ...  16.688428  48.816540
# 1462  64.494607  160.712935  98.306790  53.902985  ...  16.989121  47.794204
# 1463  63.684204  157.031406  98.092847  54.206493  ...  16.713486  47.581218
# ...         ...         ...        ...        ...  ...        ...        ...
# 2187  36.642122   72.474369  82.122833  40.135478  ...   9.144320  44.550646
# 2188  35.957933   71.026406  80.359121  39.656534  ...   9.031427  44.007345
# 2189  35.805891   68.968774  81.020513  39.656534  ...   8.946758  44.402473
# 2190  34.437513   67.825645  84.658168  38.315492  ...   8.777418  41.982316
# 2191  35.083692   69.349817  80.359121  38.794436  ...   8.890311  43.957954
#
#       sz.002077  sz.002133  sz.002146  sz.002147  sz.002208  sz.002244  \
# 1459  27.764182  22.659109  75.755892  41.114544  58.942121  37.842639
# 1460  27.896462  22.078106  74.643198  40.780488  57.804869  37.564384
# 1461  27.778880  21.967439  74.550474  40.986061  57.869855  37.786988
# 1462  27.440830  21.939772  76.683137  42.604946  57.090025  37.731337
# 1463  27.396736  21.718438  76.775861  44.455101  56.700111  37.620035
# ...         ...        ...        ...        ...        ...        ...
# 2187   8.245477   9.898329  94.664654   6.501712  34.985526  24.396432
# 2188   8.039708  10.044322  93.705215   6.364109  34.133519  24.396432
# 2189   7.907427   9.664740  93.598611   6.260907  33.654265  24.511782
# 2190   7.642866   9.518747  92.745776   6.192106  33.388013  24.684806
# 2191   7.701658   9.635541  94.238237   6.123305  33.388013  24.973180
#
#        sz.002285  sz.002377
# 1459  113.653004  38.167043
# 1460  112.515051  38.167043
# 1461  113.084028  38.167043
# 1462  112.657296  38.167043
# 1463  111.803831  38.167043
# ...          ...        ...
# 2187   54.543457  16.531075
# 2188   53.230914  16.447585
# 2189   51.189180  16.155369
# 2190   50.897504  16.197114
# 2191   51.043342  16.698056
#
# [733 rows x 52 columns]

# %% [markdown]
# #### Caculate the percentage change  and obtain the logarithm of them in order to do the OLS about individual stock

# %%
import pandas as pd
df = pd.read_csv ('final .csv',index_col = "date",parse_dates = True)
# print(df['sse180'].div(df['sse180'].shift(1)))

# %%
df.pct_change( )
# Out:
#             Unnamed: 0      seci  sz.000002  sz.000006  sz.000007  sz.000011  \
# date
# 2010-11-01         NaN       NaN        NaN        NaN        NaN        NaN
# 2010-11-02    1.000000 -0.006372   0.001037   0.000000  -0.010702   0.002312
# 2010-11-03    0.500000 -0.017911   0.019689   0.005420   0.008413   0.021915
# 2010-11-04    0.333333  0.020047  -0.009146   0.000000   0.050060  -0.002257
# 2010-11-05    0.250000  0.012323  -0.001026   0.024259   0.026107  -0.009050
# ...                ...       ...        ...        ...        ...        ...
# 2019-10-28    0.000457  0.015829  -0.003337   0.013672   0.003315   0.007315
# 2019-10-29    0.000457 -0.009383  -0.007812  -0.009634  -0.003304  -0.018672
# 2019-10-30    0.000457 -0.008563  -0.000750   0.015564  -0.006630  -0.004228
# 2019-10-31    0.000457 -0.007630  -0.004503   0.001916  -0.004449  -0.038217
# 2019-11-01    0.000456  0.012878   0.011308   0.024857   0.001117   0.018764
#
#             sz.000014  sz.000031  sz.000036  sz.000042  ...  sz.000965  \
# date                                                    ...
# 2010-11-01        NaN        NaN        NaN        NaN  ...        NaN
# 2010-11-02   0.004480   0.004144  -0.010707   0.047365  ...   0.003150
# 2010-11-03  -0.017841  -0.004127  -0.012987  -0.033352  ...  -0.006279
# 2010-11-04   0.001817   0.006906   0.019737   0.000585  ...  -0.010269
# 2010-11-05   0.017226   0.027435   0.017204   0.024547  ...   0.011173
# ...               ...        ...        ...        ...  ...        ...
# 2019-10-28   0.007415  -0.013245   0.004796   0.008307  ...   0.009346
# 2019-10-29  -0.019979  -0.021477  -0.011933   0.023687  ...  -0.012346
# 2019-10-30  -0.028970   0.008230   0.000000   0.006036  ...  -0.009375
# 2019-10-31  -0.016575   0.044898  -0.033816  -0.007000  ...  -0.018927
# 2019-11-01   0.022472  -0.050781   0.012500   0.027190  ...   0.012862
#
#             sz.002016  sz.002077  sz.002133  sz.002146  sz.002147  sz.002208  \
# date
# 2010-11-01        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-11-02   0.012257  -0.040214  -0.006676   0.007547  -0.016447   0.008137
# 2010-11-03   0.045409  -0.013966  -0.034946  -0.033708  -0.036120  -0.010492
# 2010-11-04   0.031853   0.042493   0.005571  -0.004651   0.013185   0.002447
# 2010-11-05   0.031805  -0.010870   0.008310   0.034268   0.016438   0.017901
# ...               ...        ...        ...        ...        ...        ...
# 2019-10-28   0.001110   0.031250   0.014970  -0.008929   0.016129   0.026563
# 2019-10-29  -0.012195  -0.024955   0.014749  -0.010135  -0.021164  -0.024353
# 2019-10-30   0.008979  -0.016453  -0.037791  -0.001138  -0.016216  -0.014041
# 2019-10-31  -0.054505  -0.033457  -0.015106  -0.009112  -0.010989  -0.007911
# 2019-11-01   0.047059   0.007692   0.012270   0.016092  -0.011111   0.000000
#
#             sz.002244  sz.002285  sz.002377
# date
# 2010-11-01        NaN        NaN        NaN
# 2010-11-02   0.039735  -0.007246  -0.040760
# 2010-11-03  -0.019904  -0.009051  -0.012071
# 2010-11-04   0.011373  -0.008839   0.034213
# 2010-11-05  -0.010442   0.004459  -0.013902
# ...               ...        ...        ...
# 2019-10-28  -0.034247   0.002681   0.010204
# 2019-10-29   0.000000  -0.024064  -0.005051
# 2019-10-30   0.004728  -0.038356  -0.017766
# 2019-10-31   0.007059  -0.005698   0.002584
# 2019-11-01   0.011682   0.002865   0.030928
#
# [2192 rows x 51 columns]

# %%
data = df.pct_change()
data.to_csv('sse_pc.csv')

# %%
import pandas as pd
df = pd.read_csv ('sse1.csv') 
df['seci'] = df["seci"] - df["rate"]
df['sz.000002'] = df["sz.000002"] - df["rate"]
df['sz.000006'] = df["sz.000006"] - df["rate"]
df['sz.000007'] = df["sz.000007"] - df["rate"]
df['sz.000011'] = df["sz.000011"] - df["rate"]
df['sz.000014'] = df["sz.000014"] - df["rate"]
df['sz.000031'] = df["sz.000031"] - df["rate"]
df['sz.000036'] = df["sz.000036"] - df["rate"]
df['sz.000042'] = df["sz.000042"] - df["rate"]
df['sz.000043'] = df["sz.000043"] - df["rate"]
df['sz.000046'] = df["sz.000046"] - df["rate"]
df['sz.000069'] = df["sz.000069"] - df["rate"]
df['sz.000402'] = df["sz.000402"] - df["rate"]
df['sz.000502'] = df["sz.000502"] - df["rate"]
df['sz.000514'] = df["sz.000514"] - df["rate"]
df['sz.000517'] = df['sz.000517'] - df["rate"]                    
df['sz.000537'] = df["sz.000537"] - df["rate"]
df['sz.000540'] = df["sz.000540"] - df["rate"]
df['sz.000558'] = df["sz.000558"] - df["rate"]
df['sz.000560'] = df["sz.000560"] - df["rate"]
df['sz.000573'] = df["sz.000573"] - df["rate"]                    
df['sz.000608'] = df["sz.000608"] - df["rate"]
df['sz.000615'] = df["sz.000615"] - df["rate"]
df['sz.000616'] = df["sz.000616"] - df["rate"]
df['sz.000620'] = df["sz.000620"] - df["rate"]
df['sz.000631'] = df["sz.000631"] - df["rate"]
df['sz.000656'] = df["sz.000656"] - df["rate"]
df['sz.000667'] = df["sz.000667"] - df["rate"]
df['sz.000668'] = df["sz.000668"] - df["rate"]
df['sz.000671'] = df["sz.000671"] - df["rate"]  
df['sz.000691'] = df["sz.000691"] - df["rate"]                    
df['sz.000718'] = df["sz.000718"] - df["rate"]  
df['sz.000732'] = df["sz.000732"] - df["rate"]     
df['sz.000736'] = df["sz.000736"] - df["rate"]   
df['sz.000797'] = df["sz.000797"] - df["rate"]   
df['sz.000838'] = df["sz.000838"] - df["rate"]                 
df['sz.000897'] = df["sz.000897"] - df["rate"]   
df['sz.000909'] = df["sz.000909"] - df["rate"]   
df['sz.000926'] = df["sz.000926"] - df["rate"]                   
df['sz.000961'] = df["sz.000961"] - df["rate"]                                           
df['sz.000965'] = df["sz.000965"] - df["rate"]                     
df['sz.002016'] = df["sz.002016"] - df["rate"]                    
df['sz.002077'] = df["sz.002077"] - df["rate"]                     
df['sz.002133'] = df["sz.002133"] - df["rate"]                     
df['sz.002146'] = df["sz.002146"] - df["rate"]                  
df['sz.002147'] = df["sz.002147"] - df["rate"]                       
df['sz.002208'] = df["sz.002208"] - df["rate"]
df['sz.002244'] = df["sz.002244"] - df["rate"] 
df['sz.002285'] = df["sz.002285"] - df["rate"] 
df['sz.002377'] = df["sz.002377"] - df["rate"]   
df
# Out:
#             date      seci     rate  sz.000002  sz.000006  sz.000007  \
# 0     2010-11-02 -0.006462  0.00009   0.000947  -0.000090  -0.010792
# 1     2010-11-03 -0.018001  0.00009   0.019599   0.005330   0.008323
# 2     2010-11-04  0.019957  0.00009  -0.009237  -0.000090   0.049969
# 3     2010-11-05  0.012233  0.00009  -0.001116   0.024168   0.026016
# 4     2010-11-08  0.017785  0.00009   0.016337   0.039383   0.006547
# ...          ...       ...      ...        ...        ...        ...
# 2186  2019-10-28  0.015739  0.00009  -0.003427   0.013582   0.003225
# 2187  2019-10-29 -0.009473  0.00009  -0.007903  -0.009724  -0.003394
# 2188  2019-10-30 -0.008653  0.00009  -0.000840   0.015474  -0.006720
# 2189  2019-10-31 -0.007721  0.00009  -0.004593   0.001825  -0.004540
# 2190  2019-11-01  0.012788  0.00009   0.011218   0.024766   0.001027
#
#       sz.000011  sz.000014  sz.000031  sz.000036  ...  sz.000965  sz.002016  \
# 0      0.002222   0.004390   0.004053  -0.010797  ...   0.003059   0.012167
# 1      0.021824  -0.017931  -0.004217  -0.013077  ...  -0.006370   0.045318
# 2     -0.002348   0.001726   0.006816   0.019647  ...  -0.010359   0.031763
# 3     -0.009140   0.017135   0.027345   0.017114  ...   0.011083   0.031715
# 4      0.035298   0.022191   0.011926   0.044307  ...   0.018063   0.001723
# ...         ...        ...        ...        ...  ...        ...        ...
# 2186   0.007224   0.007325  -0.013335   0.004706  ...   0.009256   0.001020
# 2187  -0.018762  -0.020069  -0.021567  -0.012023  ...  -0.012436  -0.012285
# 2188  -0.004319  -0.029060   0.008140  -0.000090  ...  -0.009465   0.008888
# 2189  -0.038307  -0.016665   0.044808  -0.033907  ...  -0.019018  -0.054595
# 2190   0.018674   0.022382  -0.050872   0.012410  ...   0.012771   0.046969
#
#       sz.002077  sz.002133  sz.002146  sz.002147  sz.002208  sz.002244  \
# 0     -0.040305  -0.006766   0.007457  -0.016538   0.008046   0.039645
# 1     -0.014057  -0.035037  -0.033798  -0.036211  -0.010583  -0.019995
# 2      0.042403   0.005481  -0.004741   0.013095   0.002357   0.011283
# 3     -0.010960   0.008220   0.034178   0.016348   0.017810  -0.010532
# 4      0.010899   0.020514   0.017982   0.011365   0.019094   0.030754
# ...         ...        ...        ...        ...        ...        ...
# 2186   0.031160   0.014880  -0.009019   0.016039   0.026472  -0.034337
# 2187  -0.025046   0.014659  -0.010225  -0.021254  -0.024443  -0.000090
# 2188  -0.016544  -0.037881  -0.001228  -0.016306  -0.014131   0.004638
# 2189  -0.033548  -0.015196  -0.009202  -0.011079  -0.008002   0.006969
# 2190   0.007602   0.012180   0.016002  -0.011201  -0.000090   0.011592
#
#       sz.002285  sz.002377
# 0     -0.007337  -0.040850
# 1     -0.009141  -0.012162
# 2     -0.008929   0.034123
# 3      0.004369  -0.013992
# 4      0.020922   0.022759
# ...         ...        ...
# 2186   0.002591   0.010114
# 2187  -0.024154  -0.005141
# 2188  -0.038446  -0.017857
# 2189  -0.005788   0.002494
# 2190   0.002775   0.030838
#
# [2191 rows x 52 columns]

# %%
data1 = df
data1.to_csv('sse4.csv')

# %% [markdown]
# ## Step 1

# %% [markdown]
# #### Now it is time to caculate the beta for 30 indidual stocks

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
import statsmodels.api as sm
df = pd.read_csv("sse5.csv", index_col = "date")
X = df['seci']
ylabes = ['sz.000002','sz.000006','sz.000007','sz.000011','sz.000014','sz.000031','sz.000036','sz.000042','sz.000043','sz.000046',
'sz.000069','sz.000402','sz.000502','sz.000514','sz.000517','sz.000537','sz.000540','sz.000558','sz.000560','sz.000573','sz.000608',
'sz.000615','sz.000616','sz.000620','sz.000631','sz.000656','sz.000667','sz.000668','sz.000671','sz.000691','sz.000718',
'sz.000732','sz.000736','sz.000797','sz.000838','sz.000897','sz.000909','sz.000926','sz.000961','sz.000965','sz.002016',
'sz.002077','sz.002133','sz.002146','sz.002147','sz.002208','sz.002244','sz.002285','sz.002377']
for y in ylabes:
    Y = df[y]
    est = sm.OLS(Y, X).fit()
    print(est.summary())
    print(est.params)
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000002   R-squared (uncentered):                   0.289
# Model:                            OLS   Adj. R-squared (uncentered):              0.288
# Method:                 Least Squares   F-statistic:                              294.2
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    1.30e-55
# Time:                        16:52:17   Log-Likelihood:                          1907.0
# No. Observations:                 726   AIC:                                     -3812.
# Df Residuals:                     725   BIC:                                     -3808.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           0.7481      0.044     17.153      0.000       0.662       0.834
# ==============================================================================
# Omnibus:                       93.910   Durbin-Watson:                   1.807
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              340.923
# Skew:                           0.568   Prob(JB):                     9.32e-75
# Kurtosis:                       6.159   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    0.748068
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000006   R-squared (uncentered):                   0.311
# Model:                            OLS   Adj. R-squared (uncentered):              0.310
# Method:                 Least Squares   F-statistic:                              327.6
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    1.05e-60
# Time:                        16:52:17   Log-Likelihood:                          1788.0
# No. Observations:                 726   AIC:                                     -3574.
# Df Residuals:                     725   BIC:                                     -3569.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           0.9301      0.051     18.101      0.000       0.829       1.031
# ==============================================================================
# Omnibus:                      188.389   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              846.390
# Skew:                           1.115   Prob(JB):                    1.62e-184
# Kurtosis:                       7.797   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    0.930093
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000007   R-squared (uncentered):                   0.193
# Model:                            OLS   Adj. R-squared (uncentered):              0.192
# Method:                 Least Squares   F-statistic:                              173.6
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    1.07e-35
# Time:                        16:52:17   Log-Likelihood:                          1645.2
# No. Observations:                 726   AIC:                                     -3288.
# Df Residuals:                     725   BIC:                                     -3284.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           0.8242      0.063     13.176      0.000       0.701       0.947
# ==============================================================================
# Omnibus:                       53.461   Durbin-Watson:                   1.724
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              211.493
# Skew:                           0.186   Prob(JB):                     1.19e-46
# Kurtosis:                       5.618   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    0.824206
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000011   R-squared (uncentered):                   0.332
# Model:                            OLS   Adj. R-squared (uncentered):              0.331
# Method:                 Least Squares   F-statistic:                              360.3
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    1.58e-65
# Time:                        16:52:17   Log-Likelihood:                          1642.1
# No. Observations:                 726   AIC:                                     -3282.
# Df Residuals:                     725   BIC:                                     -3278.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           1.1924      0.063     18.981      0.000       1.069       1.316
# ==============================================================================
# Omnibus:                      149.478   Durbin-Watson:                   1.873
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              396.409
# Skew:                           1.042   Prob(JB):                     8.34e-87
# Kurtosis:                       5.960   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    1.192396
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000014   R-squared (uncentered):                   0.290
# Model:                            OLS   Adj. R-squared (uncentered):              0.289
# Method:                 Least Squares   F-statistic:                              296.1
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    6.59e-56
# Time:                        16:52:17   Log-Likelihood:                          1587.6
# No. Observations:                 726   AIC:                                     -3173.
# Df Residuals:                     725   BIC:                                     -3169.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           1.1653      0.068     17.209      0.000       1.032       1.298
# ==============================================================================
# Omnibus:                      179.833   Durbin-Watson:                   1.724
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              693.046
# Skew:                           1.111   Prob(JB):                    3.21e-151
# Kurtosis:                       7.239   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    1.165278
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000031   R-squared (uncentered):                   0.428
# Model:                            OLS   Adj. R-squared (uncentered):              0.428
# Method:                 Least Squares   F-statistic:                              543.4
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    4.01e-90
# Time:                        16:52:17   Log-Likelihood:                          1991.8
# No. Observations:                 726   AIC:                                     -3982.
# Df Residuals:                     725   BIC:                                     -3977.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           0.9046      0.039     23.310      0.000       0.828       0.981
# ==============================================================================
# Omnibus:                      195.194   Durbin-Watson:                   1.890
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1151.141
# Skew:                           1.070   Prob(JB):                    1.08e-250
# Kurtosis:                       8.786   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    0.90462
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000036   R-squared (uncentered):                   0.307
# Model:                            OLS   Adj. R-squared (uncentered):              0.306
# Method:                 Least Squares   F-statistic:                              321.3
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    9.41e-60
# Time:                        16:52:17   Log-Likelihood:                          1794.5
# No. Observations:                 726   AIC:                                     -3587.
# Df Residuals:                     725   BIC:                                     -3582.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           0.9128      0.051     17.925      0.000       0.813       1.013
# ==============================================================================
# Omnibus:                      285.973   Durbin-Watson:                   1.704
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2043.356
# Skew:                           1.597   Prob(JB):                         0.00
# Kurtosis:                      10.573   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    0.912764
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000042   R-squared (uncentered):                   0.281
# Model:                            OLS   Adj. R-squared (uncentered):              0.280
# Method:                 Least Squares   F-statistic:                              282.8
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    7.78e-54
# Time:                        16:52:17   Log-Likelihood:                          1786.3
# No. Observations:                 726   AIC:                                     -3571.
# Df Residuals:                     725   BIC:                                     -3566.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           0.8661      0.051     16.818      0.000       0.765       0.967
# ==============================================================================
# Omnibus:                      184.139   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              673.758
# Skew:                           1.157   Prob(JB):                    4.96e-147
# Kurtosis:                       7.113   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    0.8661
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000043   R-squared (uncentered):                   0.291
# Model:                            OLS   Adj. R-squared (uncentered):              0.290
# Method:                 Least Squares   F-statistic:                              298.1
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    3.26e-56
# Time:                        16:52:17   Log-Likelihood:                          1641.2
# No. Observations:                 726   AIC:                                     -3280.
# Df Residuals:                     725   BIC:                                     -3276.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           1.0860      0.063     17.266      0.000       0.963       1.209
# ==============================================================================
# Omnibus:                      182.906   Durbin-Watson:                   1.696
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              543.789
# Skew:                           1.225   Prob(JB):                    8.27e-119
# Kurtosis:                       6.460   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    1.086004
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000046   R-squared (uncentered):                   0.305
# Model:                            OLS   Adj. R-squared (uncentered):              0.304
# Method:                 Least Squares   F-statistic:                              318.0
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    2.92e-59
# Time:                        16:52:17   Log-Likelihood:                          1785.5
# No. Observations:                 726   AIC:                                     -3569.
# Df Residuals:                     725   BIC:                                     -3564.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           0.9194      0.052     17.834      0.000       0.818       1.021
# ==============================================================================
# Omnibus:                      172.443   Durbin-Watson:                   1.801
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              587.013
# Skew:                           1.106   Prob(JB):                    3.40e-128
# Kurtosis:                       6.810   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    0.919448
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000069   R-squared (uncentered):                   0.365
# Model:                            OLS   Adj. R-squared (uncentered):              0.364
# Method:                 Least Squares   F-statistic:                              416.6
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    1.63e-73
# Time:                        16:52:17   Log-Likelihood:                          1893.2
# No. Observations:                 726   AIC:                                     -3784.
# Df Residuals:                     725   BIC:                                     -3780.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           0.9073      0.044     20.411      0.000       0.820       0.995
# ==============================================================================
# Omnibus:                       58.355   Durbin-Watson:                   1.840
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              141.922
# Skew:                           0.437   Prob(JB):                     1.52e-31
# Kurtosis:                       4.982   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    0.907298
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000402   R-squared (uncentered):                   0.458
# Model:                            OLS   Adj. R-squared (uncentered):              0.457
# Method:                 Least Squares   F-statistic:                              612.5
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    1.71e-98
# Time:                        16:52:17   Log-Likelihood:                          2137.9
# No. Observations:                 726   AIC:                                     -4274.
# Df Residuals:                     725   BIC:                                     -4269.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           0.7853      0.032     24.748      0.000       0.723       0.848
# ==============================================================================
# Omnibus:                       42.747   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               86.402
# Skew:                           0.369   Prob(JB):                     1.73e-19
# Kurtosis:                       4.521   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    0.785323
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000502   R-squared (uncentered):                   0.347
# Model:                            OLS   Adj. R-squared (uncentered):              0.346
# Method:                 Least Squares   F-statistic:                              385.7
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    3.50e-69
# Time:                        16:52:17   Log-Likelihood:                          1725.1
# No. Observations:                 726   AIC:                                     -3448.
# Df Residuals:                     725   BIC:                                     -3444.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           1.1004      0.056     19.639      0.000       0.990       1.210
# ==============================================================================
# Omnibus:                      187.218   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              685.176
# Skew:                           1.177   Prob(JB):                    1.64e-149
# Kurtosis:                       7.136   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    1.100394
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000514   R-squared (uncentered):                   0.375
# Model:                            OLS   Adj. R-squared (uncentered):              0.374
# Method:                 Least Squares   F-statistic:                              434.8
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    5.29e-76
# Time:                        16:52:17   Log-Likelihood:                          1870.3
# No. Observations:                 726   AIC:                                     -3739.
# Df Residuals:                     725   BIC:                                     -3734.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           0.9566      0.046     20.851      0.000       0.866       1.047
# ==============================================================================
# Omnibus:                      311.531   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3985.774
# Skew:                           1.568   Prob(JB):                         0.00
# Kurtosis:                      14.042   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    0.956552
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000517   R-squared (uncentered):                   0.285
# Model:                            OLS   Adj. R-squared (uncentered):              0.284
# Method:                 Least Squares   F-statistic:                              289.0
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    8.59e-55
# Time:                        16:52:17   Log-Likelihood:                          1777.2
# No. Observations:                 726   AIC:                                     -3552.
# Df Residuals:                     725   BIC:                                     -3548.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           0.8865      0.052     16.999      0.000       0.784       0.989
# ==============================================================================
# Omnibus:                       81.168   Durbin-Watson:                   1.921
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              463.857
# Skew:                           0.293   Prob(JB):                    1.88e-101
# Kurtosis:                       6.872   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    0.886467
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000537   R-squared (uncentered):                   0.376
# Model:                            OLS   Adj. R-squared (uncentered):              0.375
# Method:                 Least Squares   F-statistic:                              436.7
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    2.91e-76
# Time:                        16:52:17   Log-Likelihood:                          1742.3
# No. Observations:                 726   AIC:                                     -3483.
# Df Residuals:                     725   BIC:                                     -3478.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           1.1435      0.055     20.897      0.000       1.036       1.251
# ==============================================================================
# Omnibus:                      143.141   Durbin-Watson:                   1.947
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              449.098
# Skew:                           0.942   Prob(JB):                     3.02e-98
# Kurtosis:                       6.362   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    1.143487
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000540   R-squared (uncentered):                   0.360
# Model:                            OLS   Adj. R-squared (uncentered):              0.359
# Method:                 Least Squares   F-statistic:                              407.0
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    3.48e-72
# Time:                        16:52:17   Log-Likelihood:                          1730.8
# No. Observations:                 726   AIC:                                     -3460.
# Df Residuals:                     725   BIC:                                     -3455.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           1.1216      0.056     20.175      0.000       1.012       1.231
# ==============================================================================
# Omnibus:                      114.565   Durbin-Watson:                   1.790
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              341.042
# Skew:                           0.771   Prob(JB):                     8.78e-75
# Kurtosis:                       5.983   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    1.12156
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000558   R-squared (uncentered):                   0.265
# Model:                            OLS   Adj. R-squared (uncentered):              0.264
# Method:                 Least Squares   F-statistic:                              261.1
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    2.18e-50
# Time:                        16:52:17   Log-Likelihood:                          1689.9
# No. Observations:                 726   AIC:                                     -3378.
# Df Residuals:                     725   BIC:                                     -3373.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           0.9503      0.059     16.158      0.000       0.835       1.066
# ==============================================================================
# Omnibus:                      218.038   Durbin-Watson:                   1.862
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1089.969
# Skew:                           1.271   Prob(JB):                    2.07e-237
# Kurtosis:                       8.438   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    0.950292
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000560   R-squared (uncentered):                   0.321
# Model:                            OLS   Adj. R-squared (uncentered):              0.320
# Method:                 Least Squares   F-statistic:                              342.5
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    6.43e-63
# Time:                        16:52:17   Log-Likelihood:                          1916.2
# No. Observations:                 726   AIC:                                     -3830.
# Df Residuals:                     725   BIC:                                     -3826.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           0.7969      0.043     18.506      0.000       0.712       0.881
# ==============================================================================
# Omnibus:                      302.675   Durbin-Watson:                   1.705
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3638.839
# Skew:                           1.530   Prob(JB):                         0.00
# Kurtosis:                      13.532   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    0.796926
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000573   R-squared (uncentered):                   0.374
# Model:                            OLS   Adj. R-squared (uncentered):              0.373
# Method:                 Least Squares   F-statistic:                              433.7
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    7.34e-76
# Time:                        16:52:17   Log-Likelihood:                          1979.0
# No. Observations:                 726   AIC:                                     -3956.
# Df Residuals:                     725   BIC:                                     -3951.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           0.8226      0.039     20.826      0.000       0.745       0.900
# ==============================================================================
# Omnibus:                      125.644   Durbin-Watson:                   1.758
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1740.007
# Skew:                           0.266   Prob(JB):                         0.00
# Kurtosis:                      10.566   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    0.82259
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000608   R-squared (uncentered):                   0.333
# Model:                            OLS   Adj. R-squared (uncentered):              0.332
# Method:                 Least Squares   F-statistic:                              361.8
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    9.65e-66
# Time:                        16:52:17   Log-Likelihood:                          2003.6
# No. Observations:                 726   AIC:                                     -4005.
# Df Residuals:                     725   BIC:                                     -4001.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           0.7261      0.038     19.020      0.000       0.651       0.801
# ==============================================================================
# Omnibus:                      129.687   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2168.475
# Skew:                           0.181   Prob(JB):                         0.00
# Kurtosis:                      11.459   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    0.726134
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000615   R-squared (uncentered):                   0.330
# Model:                            OLS   Adj. R-squared (uncentered):              0.330
# Method:                 Least Squares   F-statistic:                              357.8
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    3.57e-65
# Time:                        16:52:17   Log-Likelihood:                          1869.4
# No. Observations:                 726   AIC:                                     -3737.
# Df Residuals:                     725   BIC:                                     -3732.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           0.8689      0.046     18.917      0.000       0.779       0.959
# ==============================================================================
# Omnibus:                      194.662   Durbin-Watson:                   1.782
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1092.623
# Skew:                           1.082   Prob(JB):                    5.50e-238
# Kurtosis:                       8.607   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    0.868855
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000616   R-squared (uncentered):                   0.361
# Model:                            OLS   Adj. R-squared (uncentered):              0.360
# Method:                 Least Squares   F-statistic:                              409.4
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    1.64e-72
# Time:                        16:52:17   Log-Likelihood:                          1884.3
# No. Observations:                 726   AIC:                                     -3767.
# Df Residuals:                     725   BIC:                                     -3762.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           0.9105      0.045     20.233      0.000       0.822       0.999
# ==============================================================================
# Omnibus:                      329.804   Durbin-Watson:                   1.618
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2747.806
# Skew:                           1.844   Prob(JB):                         0.00
# Kurtosis:                      11.788   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    0.910461
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000620   R-squared (uncentered):                   0.008
# Model:                            OLS   Adj. R-squared (uncentered):              0.006
# Method:                 Least Squares   F-statistic:                              5.597
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                      0.0183
# Time:                        16:52:17   Log-Likelihood:                          415.72
# No. Observations:                 726   AIC:                                     -829.4
# Df Residuals:                     725   BIC:                                     -824.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           0.8048      0.340      2.366      0.018       0.137       1.473
# ==============================================================================
# Omnibus:                     1864.139   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         14402392.104
# Skew:                          25.967   Prob(JB):                         0.00
# Kurtosis:                     691.052   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    0.80482
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000631   R-squared (uncentered):                   0.312
# Model:                            OLS   Adj. R-squared (uncentered):              0.311
# Method:                 Least Squares   F-statistic:                              329.4
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    5.72e-61
# Time:                        16:52:17   Log-Likelihood:                          1691.2
# No. Observations:                 726   AIC:                                     -3380.
# Df Residuals:                     725   BIC:                                     -3376.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           1.0656      0.059     18.149      0.000       0.950       1.181
# ==============================================================================
# Omnibus:                      225.841   Durbin-Watson:                   1.840
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1042.662
# Skew:                           1.350   Prob(JB):                    3.88e-227
# Kurtosis:                       8.213   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    1.065565
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.000656   R-squared (uncentered):                   0.237
# Model:                            OLS   Adj. R-squared (uncentered):              0.236
# Method:                 Least Squares   F-statistic:                              225.4
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    1.45e-44
# Time:                        16:52:17   Log-Likelihood:                          1689.6
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           0.9532      0.057     16.822      0.000       0.842       1.064
# ==============================================================================
# Omnibus:                       61.698   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              316.509
# Skew:                           0.106   Prob(JB):                     1.87e-69
# Kurtosis:                       6.228   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    0.953201
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.002077   R-squared (uncentered):                   0.430
# Model:                            OLS   Adj. R-squared (uncentered):              0.429
# Method:                 Least Squares   F-statistic:                              546.5
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    1.63e-90
# Time:                        16:52:18   Log-Likelihood:                          1764.1
# No. Observations:                 726   AIC:                                     -3526.
# Df Residuals:                     725   BIC:                                     -3522.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           1.2413      0.053     23.378      0.000       1.137       1.346
# ==============================================================================
# Omnibus:                      231.775   Durbin-Watson:                   1.930
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1433.713
# Skew:                           1.288   Prob(JB):                         0.00
# Kurtosis:                       9.384   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    1.241339
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.002133   R-squared (uncentered):                   0.445
# Model:                            OLS   Adj. R-squared (uncentered):              0.444
# Method:                 Least Squares   F-statistic:                              580.2
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    1.24e-94
# Time:                        16:52:18   Log-Likelihood:                          1991.2
# No. Observations:                 726   AIC:                                     -3980.
# Df Residuals:                     725   BIC:                                     -3976.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           0.9355      0.039     24.086      0.000       0.859       1.012
# ==============================================================================
# Omnibus:                      153.368   Durbin-Watson:                   1.914
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              532.339
# Skew:                           0.975   Prob(JB):                    2.54e-116
# Kurtosis:                       6.715   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    0.935511
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.002146   R-squared (uncentered):                   0.241
# Model:                            OLS   Adj. R-squared (uncentered):              0.240
# Method:                 Least Squares   F-statistic:                              229.7
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    2.84e-45
# Time:                        16:52:18   Log-Likelihood:                          1634.1
# No. Observations:                 726   AIC:                                     -3266.
# Df Residuals:                     725   BIC:                                     -3262.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           0.9625      0.064     15.155      0.000       0.838       1.087
# ==============================================================================
# Omnibus:                       19.046   Durbin-Watson:                   1.823
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.822
# Skew:                           0.115   Prob(JB):                     1.01e-08
# Kurtosis:                       4.079   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    0.96254
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.002147   R-squared (uncentered):                   0.459
# Model:                            OLS   Adj. R-squared (uncentered):              0.458
# Method:                 Least Squares   F-statistic:                              614.0
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    1.15e-98
# Time:                        16:52:18   Log-Likelihood:                          1908.7
# No. Observations:                 726   AIC:                                     -3815.
# Df Residuals:                     725   BIC:                                     -3811.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           1.0781      0.044     24.778      0.000       0.993       1.164
# ==============================================================================
# Omnibus:                      199.123   Durbin-Watson:                   1.837
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1452.276
# Skew:                           1.027   Prob(JB):                         0.00
# Kurtosis:                       9.617   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    1.078103
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.002208   R-squared (uncentered):                   0.402
# Model:                            OLS   Adj. R-squared (uncentered):              0.401
# Method:                 Least Squares   F-statistic:                              486.6
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    6.62e-83
# Time:                        16:52:18   Log-Likelihood:                          1832.1
# No. Observations:                 726   AIC:                                     -3662.
# Df Residuals:                     725   BIC:                                     -3658.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           1.0667      0.048     22.060      0.000       0.972       1.162
# ==============================================================================
# Omnibus:                      261.032   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1284.285
# Skew:                           1.564   Prob(JB):                    1.32e-279
# Kurtosis:                       8.716   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    1.066719
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.002244   R-squared (uncentered):                   0.340
# Model:                            OLS   Adj. R-squared (uncentered):              0.339
# Method:                 Least Squares   F-statistic:                              373.0
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    2.25e-67
# Time:                        16:52:18   Log-Likelihood:                          1778.7
# No. Observations:                 726   AIC:                                     -3555.
# Df Residuals:                     725   BIC:                                     -3551.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           1.0052      0.052     19.314      0.000       0.903       1.107
# ==============================================================================
# Omnibus:                       27.825   Durbin-Watson:                   1.874
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.201
# Skew:                           0.367   Prob(JB):                     8.35e-09
# Kurtosis:                       3.831   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    1.005238
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.002285   R-squared (uncentered):                   0.294
# Model:                            OLS   Adj. R-squared (uncentered):              0.293
# Method:                 Least Squares   F-statistic:                              301.4
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    1.02e-56
# Time:                        16:52:18   Log-Likelihood:                          1700.0
# No. Observations:                 726   AIC:                                     -3398.
# Df Residuals:                     725   BIC:                                     -3394.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           1.0069      0.058     17.361      0.000       0.893       1.121
# ==============================================================================
# Omnibus:                       60.298   Durbin-Watson:                   1.866
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              170.544
# Skew:                           0.401   Prob(JB):                     9.27e-38
# Kurtosis:                       5.235   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    1.00691
# dtype: float64
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              sz.002377   R-squared (uncentered):                   0.362
# Model:                            OLS   Adj. R-squared (uncentered):              0.361
# Method:                 Least Squares   F-statistic:                              412.0
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):                    7.04e-73
# Time:                        16:52:18   Log-Likelihood:                          1735.8
# No. Observations:                 726   AIC:                                     -3470.
# Df Residuals:                     725   BIC:                                     -3465.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# seci           1.1208      0.055     20.298      0.000       1.012       1.229
# ==============================================================================
# Omnibus:                      197.271   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              746.419
# Skew:                           1.232   Prob(JB):                    8.26e-163
# Kurtosis:                       7.313   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# seci    1.120757
# dtype: float64

# %% [markdown]
# #### Save all the beta and R-Squares for all the 30 invidual stocks in one excel and sort them from smallest to the biggest based on Betas

# %%
import pandas as pd
stexcel=pd.read_excel('single_stock.xlsx')
stexcel.sort_values(by='Beta',inplace=True,ascending=True)
print(stexcel)
# Out:
#    Unnamed: 0    Beta  R-Square  Unnamed: 3       Code    Beta.1       R^2
# 0   sz.000667  0.7238     0.454         NaN  sz.000667  0.725114  0.461066
# 1   sz.000608  0.7261     0.333         NaN  sz.000608  0.727107  0.333977
# 2   sz.000002  0.7481     0.289         NaN  sz.000002  0.747721  0.290086
# 3   sz.000668  0.7489     0.329         NaN  sz.000668  0.756321  0.335146
# 4   sz.000402  0.7853     0.458         NaN  sz.000402  0.785577  0.459542
# 5   sz.000691  0.7932     0.199         NaN  sz.000691  0.800251  0.203955
# 6   sz.000560  0.7969     0.321         NaN  sz.000560  0.800773  0.327711
# 7   sz.000573  0.8226     0.374         NaN  sz.000007  0.827144  0.196104
# 8   sz.000007  0.8242     0.193         NaN  sz.000573  0.828335  0.378334
# 9   sz.000732  0.8383     0.226         NaN  sz.000732  0.845309  0.231227
# 10  sz.000965  0.8627     0.328         NaN  sz.000965  0.864200  0.332336
# 11  sz.000042  0.8661     0.281         NaN  sz.000042  0.872208  0.288525
# 12  sz.000615  0.8689     0.330         NaN  sz.000615  0.873954  0.333334
# 13  sz.000838  0.8758     0.289         NaN  sz.000656  0.885929  0.239703
# 14  sz.000656  0.8835     0.237         NaN  sz.000838  0.887087  0.295348
# 15  sz.000517  0.8865     0.285         NaN  sz.000517  0.891018  0.287684
# 16  sz.000031  0.9046     0.428         NaN  sz.000031  0.906178  0.433640
# 17  sz.000069  0.9073     0.365         NaN  sz.000069  0.908160  0.367721
# 18  sz.000616  0.9105     0.361         NaN  sz.000616  0.914459  0.370143
# 19  sz.000036  0.9128     0.307         NaN  sz.000036  0.921878  0.316872
# 20  sz.000046  0.9194     0.305         NaN  sz.000046  0.923346  0.311417
# 21  sz.000006  0.9301     0.311         NaN  sz.000006  0.938847  0.319623
# 22  sz.002133  0.9355     0.445         NaN  sz.002133  0.940451  0.449794
# 23  sz.000558  0.9503     0.265         NaN  sz.000514  0.959971  0.380969
# 24  sz.002016  0.9532     0.281         NaN  sz.000558  0.960056  0.272944
# 25  sz.000514  0.9566     0.375         NaN  sz.002016  0.960392  0.283670
# 26  sz.000671  0.9622     0.249         NaN  sz.002146  0.962478  0.241612
# 27  sz.000961  0.9625     0.258         NaN  sz.000961  0.965639  0.260676
# 28  sz.002146  0.9625     0.241         NaN  sz.000671  0.968109  0.256923
# 29  sz.000797  0.9687     0.306         NaN  sz.000797  0.975346  0.314712
# 30  sz.000897  0.9765     0.325         NaN  sz.000897  0.981657  0.330353
# 31  sz.000718  1.0052     0.321         NaN  sz.002244  1.006867  0.342377
# 32  sz.002244  1.0052     0.340         NaN  sz.000718  1.008099  0.323214
# 33  sz.002285  1.0069     0.294         NaN  sz.002285  1.010801  0.296965
# 34  sz.000926  1.0535     0.405         NaN  sz.000961  1.056652  0.407997
# 35  sz.000631  1.0656     0.312         NaN  sz.000631  1.071093  0.320396
# 36  sz.002208  1.0667     0.402         NaN  sz.002208  1.072065  0.410389
# 37  sz.002147  1.0781     0.459         NaN  sz.002147  1.084942  0.464140
# 38  sz.000736  1.0812     0.293         NaN  sz.000736  1.086932  0.300991
# 39  sz.000043  1.0860     0.291         NaN  sz.000043  1.093400  0.301153
# 40  sz.000502  1.1004     0.347         NaN  sz.000502  1.112003  0.354278
# 41  sz.002377  1.1208     0.362         NaN  sz.002377  1.126322  0.369870
# 42  sz.000540  1.1216     0.360         NaN  sz.000540  1.128372  0.365860
# 43  sz.000537  1.1435     0.376         NaN  sz.000537  1.148182  0.382133
# 44  sz.000014  1.1653     0.290         NaN  sz.000014  1.178673  0.299479
# 45  sz.000011  1.1924     0.332         NaN  sz.000011  1.205825  0.341468
# 46  sz.000909  1.2205     0.467         NaN  sz.000909  1.227875  0.474608
# 47  sz.002077  1.2413     0.430         NaN  sz.002077  1.254025  0.438725

# %%
stexcel.to_excel('individual_beta.xlsx')

# %% [markdown]
# ## Step 2

# %% [markdown]
# #### Group all the 30 individual stocks into five groups , each group has five individual stocks

# %% [markdown]
# #### Now we start to use the second period data from 2015-10-08 to 2017-10-08 to caculate the betas for those five groups

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('second_group1.xlsx',sheet_name = 'sheet1')
df['first_group'] = df[['sz.000002','sz.000402','sz.000560','sz.000573','sz.000608','sz.000667','sz.000668','sz.000691']].mean(axis=1)
print (df['first_group'])
df.to_excel('second_group1.xlsx',sheet_name = 'sheet1')
# Out:
# 0      0.002157
# 1      0.001117
# 2      0.002301
# 3     -0.010892
# 4     -0.007650
#          ...
# 727    0.001652
# 728    0.011094
# 729   -0.003939
# 730   -0.005573
# 731    0.005732
# Name: first_group, Length: 732, dtype: float64

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
df = pd.read_excel('second_group1.xlsx',sheet_name = 'sheet1')
X = df['seci']
y = df['first_group']
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            first_group   R-squared:                       0.698
# Model:                            OLS   Adj. R-squared:                  0.697
# Method:                 Least Squares   F-statistic:                     1686.
# Date:                Thu, 26 Nov 2020   Prob (F-statistic):          6.66e-192
# Time:                        19:30:01   Log-Likelihood:                 2260.5
# No. Observations:                 732   AIC:                            -4517.
# Df Residuals:                     730   BIC:                            -4508.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0006      0.000      1.448      0.148      -0.000       0.001
# seci           0.8357      0.020     41.062      0.000       0.796       0.876
# ==============================================================================
# Omnibus:                       47.974   Durbin-Watson:                   1.902
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               72.992
# Skew:                           0.504   Prob(JB):                     1.41e-16
# Kurtosis:                       4.173   Cond. No.                         49.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from regression import Regression
reg = Regression()
print(reg)
# Out:
# You created an instance of Stats
# <regression.Regression object at 0x00000202E9DA9190>

# %%
import pandas as pd  
import copy
from stats import *    
  
class Regression:  
    def __init__(self):  
        self.stats = stats()  
          
    def OLS(self, reg_name, data, y_name, beta_names, 
            min_val = 0,  
                max_val = None, constant = True):  
        self.min_val = min_val  
        if max_val != None:  
            self.max_val = max_val  
        else:  
            self.max_val = len(data)  
        self.reg_name = reg_name  
        self.y_name = y_name  
        self.beta_names = copy.copy(beta_names)
        self.data = data.copy()  
        if constant:  
            self.add_constant()  
  
    def add_constant(self):  
        self.data["Constant"] = 1  
        self.beta_names.append("Constant")

# %%
import pandas as pd
from regression import Regression

# %%
reg = Regression()
print(reg)
# Out:
# You created an instance of Stats
# <regression.Regression object at 0x00000202E9D755B0>

# %%
reg

# %%
# Selecting Variables
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
data = pd.read_excel('second_group1.xlsx',sheet_name = 'sheet1')
y_var = ['first_group']
x_var = ['seci']
reg.OLS(reg_name = "stock", data = data, y_name = y_var, beta_names = x_var)
# reg.data

# %%
#regression.py
# . . . 
def calculate_regression_stats(self):
    self.sum_square_stats()
    self.calculate_degrees_of_freedom()
    self.calculate_estimator_variance()
    self.calculate_covariance_matrix()

def calculate_degrees_of_freedom(self):  
    # Degrees of freedom compares the number of observations to the number  
    # of exogenous variables used to form the prediction  
    self.lost_degrees_of_freedom = len(self.estimates)  
    self.num_obs = self.max_val + 1 - self.min_val  
    self.degrees_of_freedom = self.num_obs - self.lost_degrees_of_freedom  
         
def calculate_estimator_variance(self):  
    # estimator variance is the sse normalized by the degrees of freedom  
    # thus, estimator variance increases as the number of exogenous  
    # variables used in estimation increases(i.e., as degrees of freedom   
    # fall)  
    self.estimator_variance = self.sse / self.degrees_of_freedom  

def calculate_covariance_matrix(self):  
    # Covariance matrix will be used to estimate standard errors for  
    # each coefficient.  
    # estimator variance * (X'X)**-1  
    self.cov_matrix = float(self.estimator_variance) * self.X_transp_X_inv  
    self.cov_matrix = pd.DataFrame(self.cov_matrix,  
                                   columns = self.beta_names,  
                                   index = self.beta_names)

# %%
reg = Regression()
reg.OLS("group1", data, y_var, x_var)
# Out:
# You created an instance of Stats

# %%
reg.ssr, reg.sse, reg.sst

reg.stats_DF
# Out:
#            Estimation Statistics
# r**2                    0.697861
# Adj. r**2               0.697448
# f-stat               1688.418977
# Est Var                 0.000122
# MSE                     0.011038
# SSE                     0.089065
# SSR                     0.205717
# SST                     0.294783
# Obs.                  733.000000
# DOF                   731.000000

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('second_group2.xlsx',sheet_name = 'sheet1')
df['second_group'] = df[['sz.000007','sz.000732', 'sz.000965', 'sz.000042' ,'sz.000615','sz.000838', 'sz.000656', 'sz.000517']].mean(axis=1)
print (df['second_group'])
df.to_excel('second_group2.xlsx',sheet_name = 'sheet1')
# Out:
# 0      0.002561
# 1     -0.000983
# 2      0.003365
# 3     -0.009405
# 4     -0.011137
#          ...
# 727   -0.002775
# 728    0.015394
# 729    0.005108
# 730   -0.016838
# 731   -0.002837
# Name: second_group, Length: 732, dtype: float64

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
df = pd.read_excel('second_group2.xlsx',sheet_name = 'sheet1')
X = df['seci']
y = df['second_group']
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           second_group   R-squared:                       0.719
# Model:                            OLS   Adj. R-squared:                  0.719
# Method:                 Least Squares   F-statistic:                     1867.
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):          2.20e-203
# Time:                        17:15:39   Log-Likelihood:                 2185.1
# No. Observations:                 732   AIC:                            -4366.
# Df Residuals:                     730   BIC:                            -4357.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.000      1.140      0.255      -0.000       0.001
# seci           0.9749      0.023     43.214      0.000       0.931       1.019
# ==============================================================================
# Omnibus:                       64.398   Durbin-Watson:                   1.679
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              125.104
# Skew:                           0.553   Prob(JB):                     6.82e-28
# Kurtosis:                       4.697   Cond. No.                         49.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Selecting Variables
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
data = pd.read_excel('second_group2.xlsx',sheet_name = 'sheet1')
y_var = ['second_group']
x_var = ['seci']
reg.OLS(reg_name = "stock", data = data, y_name = y_var, beta_names = x_var)
# reg.data

# %%
reg = Regression()
reg.OLS("group2", data, y_var, x_var)
# Out:
# You created an instance of Stats

# %%
reg.ssr, reg.sse, reg.sst

reg.stats_DF
# Out:
#            Estimation Statistics
# r**2                    0.791302
# Adj. r**2               0.791016
# f-stat               2771.667733
# Est Var                 0.000132
# MSE                     0.011508
# SSE                     0.096804
# SSR                     0.367043
# SST                     0.463847
# Obs.                  733.000000
# DOF                   731.000000

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('second_group3.xlsx',sheet_name = 'sheet1')
df['third_group'] = df[['sz.000031','sz.000069','sz.000616','sz.000036','sz.000046','sz.000006','sz.002133','sz.000558']].mean(axis=1)
print (df['third_group'])
df.to_excel('second_group3.xlsx',sheet_name = 'sheet1')
# Out:
# 0     -0.003747
# 1     -0.004783
# 2      0.012032
# 3     -0.002128
# 4      0.006009
#          ...
# 727    0.013618
# 728    0.009502
# 729   -0.009160
# 730   -0.016054
# 731   -0.000732
# Name: third_group, Length: 732, dtype: float64

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
df = pd.read_excel('second_group3.xlsx',sheet_name = 'sheet1')
X = df['seci']
y = df['third_group']
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            third_group   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.741
# Method:                 Least Squares   F-statistic:                     2088.
# Date:                Thu, 26 Nov 2020   Prob (F-statistic):          2.66e-216
# Time:                        21:08:12   Log-Likelihood:                 2145.9
# No. Observations:                 732   AIC:                            -4288.
# Df Residuals:                     730   BIC:                            -4279.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.000      0.972      0.331      -0.000       0.001
# seci           1.0875      0.024     45.694      0.000       1.041       1.134
# ==============================================================================
# Omnibus:                       69.374   Durbin-Watson:                   1.759
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              134.473
# Skew:                           0.591   Prob(JB):                     6.30e-30
# Kurtosis:                       4.736   Cond. No.                         49.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Selecting Variables
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
data = pd.read_excel('second_group3.xlsx',sheet_name = 'sheet1')
y_var = ['third_group']
x_var = ['seci']
reg.OLS(reg_name = "group3", data = data, y_name = y_var, beta_names = x_var)
# reg.data

# %%
reg = Regression()
reg.OLS("group3", data, y_var, x_var)
# Out:
# You created an instance of Stats

# %%
reg.ssr, reg.sse, reg.sst
reg.stats_DF
# Out:
#            Estimation Statistics
# r**2                    0.740942
# Adj. r**2               0.740587
# f-stat               2090.758000
# Est Var                 0.000167
# MSE                     0.012909
# SSE                     0.121811
# SSR                     0.348395
# SST                     0.470206
# Obs.                  733.000000
# DOF                   731.000000

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('second_group4.xlsx',sheet_name = 'sheet1')
df['fourth_group'] = df[[ 'sz.002016', 'sz.000514', 'sz.000671', 'sz.000961' ,'sz.002146', 'sz.000797', 'sz.000897', 'sz.000718']].mean(axis=1)
print (df['fourth_group'])
df.to_excel('second_group4.xlsx',sheet_name = 'sheet1')
# Out:
# 0      0.002594
# 1      0.007962
# 2      0.014483
# 3     -0.017804
# 4     -0.009187
#          ...
# 727    0.002628
# 728    0.011476
# 729    0.010142
# 730   -0.012377
# 731   -0.000914
# Name: fourth_group, Length: 732, dtype: float64

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
df = pd.read_excel('second_group4.xlsx',sheet_name = 'sheet1')
X = df['seci']
y = df['fourth_group']
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           fourth_group   R-squared:                       0.718
# Model:                            OLS   Adj. R-squared:                  0.717
# Method:                 Least Squares   F-statistic:                     1855.
# Date:                Thu, 26 Nov 2020   Prob (F-statistic):          1.36e-202
# Time:                        21:21:20   Log-Likelihood:                 2095.6
# No. Observations:                 732   AIC:                            -4187.
# Df Residuals:                     730   BIC:                            -4178.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.001      0.394      0.694      -0.001       0.001
# seci           1.0979      0.025     43.065      0.000       1.048       1.148
# ==============================================================================
# Omnibus:                       66.234   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              147.052
# Skew:                           0.524   Prob(JB):                     1.17e-32
# Kurtosis:                       4.930   Cond. No.                         49.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Selecting Variables
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
data = pd.read_excel('second_group4.xlsx',sheet_name = 'sheet1')
y_var = ['fourth_group']
x_var = ['seci']
reg.OLS(reg_name = "group4", data = data, y_name = y_var, beta_names = x_var)
# reg.data

# %%
reg = Regression()
reg.OLS("group4", data, y_var, x_var)
# Out:
# You created an instance of Stats

# %%
reg.ssr, reg.sse, reg.sst
reg.stats_DF
# Out:
#            Estimation Statistics
# r**2                    0.717554
# Adj. r**2               0.717168
# f-stat               1857.104799
# Est Var                 0.000191
# MSE                     0.013827
# SSE                     0.139762
# SSR                     0.355064
# SST                     0.494826
# Obs.                  733.000000
# DOF                   731.000000

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('second_group5.xlsx',sheet_name = 'sheet1')
df['fifth_group'] = df[['sz.002244', 'sz.002285', 'sz.000926', 'sz.000631', 'sz.002208', 'sz.002147', 'sz.000736', 'sz.000043']].mean(axis=1)
print (df['fifth_group'])
df.to_excel('second_group5.xlsx',sheet_name = 'sheet1')
# Out:
# 0     -0.003409
# 1      0.003186
# 2      0.006230
# 3     -0.011449
# 4     -0.002750
#          ...
# 727    0.009601
# 728   -0.007337
# 729   -0.004912
# 730    0.002806
# 731    0.012401
# Name: fifth_group, Length: 732, dtype: float64

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
df = pd.read_excel('second_group5.xlsx',sheet_name = 'sheet1')
X = df['seci']
y = df['fifth_group']
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            fifth_group   R-squared:                       0.748
# Model:                            OLS   Adj. R-squared:                  0.747
# Method:                 Least Squares   F-statistic:                     2162.
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):          1.96e-220
# Time:                        17:17:50   Log-Likelihood:                 2175.1
# No. Observations:                 732   AIC:                            -4346.
# Df Residuals:                     730   BIC:                            -4337.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.000      1.188      0.235      -0.000       0.001
# seci           1.0634      0.023     46.501      0.000       1.019       1.108
# ==============================================================================
# Omnibus:                       52.766   Durbin-Watson:                   1.869
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              110.905
# Skew:                           0.437   Prob(JB):                     8.27e-25
# Kurtosis:                       4.695   Cond. No.                         49.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Selecting Variables
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
data = pd.read_excel('second_group5.xlsx',sheet_name = 'sheet1')
y_var = ['fifth_group']
x_var = ['seci']
reg.OLS(reg_name = "group5", data = data, y_name = y_var, beta_names = x_var)
# reg.data

# %%
reg = Regression()
reg.OLS("group5", data, y_var, x_var)
# Out:
# You created an instance of Stats

# %%
reg.ssr, reg.sse, reg.sst
reg.stats_DF
# Out:
#            Estimation Statistics
# r**2                    0.747606
# Adj. r**2               0.747260
# f-stat               2165.260554
# Est Var                 0.000154
# MSE                     0.012404
# SSE                     0.112465
# SSR                     0.333127
# SST                     0.445591
# Obs.                  733.000000
# DOF                   731.000000

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('second_group6.xlsx',sheet_name = 'sheet1')
df['sixth_group'] = df[['sz.000502', 'sz.002377', 'sz.000540', 'sz.000537', 'sz.000014', 'sz.000011' ,'sz.000909', 'sz.002077']].mean(axis=1)
print (df['sixth_group'])
df.to_excel('second_group6.xlsx',sheet_name = 'sheet1')
# Out:
# 0     -0.002742
# 1      0.007667
# 2      0.009762
# 3     -0.005197
# 4     -0.011040
#          ...
# 727    0.003167
# 728   -0.002649
# 729   -0.004601
# 730   -0.011528
# 731    0.009335
# Name: sixth_group, Length: 732, dtype: float64

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
df = pd.read_excel('second_group6.xlsx',sheet_name = 'sheet1')
X = df['seci']
y = df['sixth_group']
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            sixth_group   R-squared:                       0.791
# Model:                            OLS   Adj. R-squared:                  0.791
# Method:                 Least Squares   F-statistic:                     2768.
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):          1.40e-250
# Time:                        17:19:37   Log-Likelihood:                 2230.0
# No. Observations:                 732   AIC:                            -4456.
# Df Residuals:                     730   BIC:                            -4447.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0006      0.000      1.333      0.183      -0.000       0.001
# seci           1.1163      0.021     52.611      0.000       1.075       1.158
# ==============================================================================
# Omnibus:                       27.871   Durbin-Watson:                   1.731
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               66.980
# Skew:                           0.128   Prob(JB):                     2.85e-15
# Kurtosis:                       4.460   Cond. No.                         49.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Selecting Variables
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
data = pd.read_excel('second_group6.xlsx',sheet_name = 'sheet1')
y_var = ['sixth_group']
x_var = ['seci']
reg.OLS(reg_name = "group6", data = data, y_name = y_var, beta_names = x_var)
# reg.data

# %%
reg = Regression()
reg.OLS("group6", data, y_var, x_var)
# Out:
# You created an instance of Stats

# %%
reg.ssr, reg.sse, reg.sst
reg.stats_DF
# Out:
#            Estimation Statistics
# r**2                    0.791302
# Adj. r**2               0.791016
# f-stat               2771.667733
# Est Var                 0.000132
# MSE                     0.011508
# SSE                     0.096804
# SSR                     0.367043
# SST                     0.463847
# Obs.                  733.000000
# DOF                   731.000000

# %% [markdown]
# ## Step 3

# %% [markdown]
# #### Cross sectional analysis: analyze whether there is positive correlation between system risk and market risk as expected by CAPM.
# Use the data of third period from 2016-11-01 to 2019-11-01 and the betas obtained from step 2, regress between portofolio average daily stock return and group betas.
#
# Regression equation is as below:
#
#                                      R_pi=γ_0+γ_1β_pi+ε_i              (4)
#
# In equation (4), R_pi is the daily average return from 2013-11-01 to 2016-10-31, γ_0 and γ_1 are the coefficients which need to be estimated, ε_i is residual error

# %% [markdown]
# #### Caculate the average return for those six portfolios

# %%
df = pd.read_excel('third period _group 1.xlsx',sheet_name = 'sheet1')
df.mean()
# df.to_excel('second_group6.xlsx',sheet_name = 'sheet1')
# Out:
# sz.000667   -0.000458
# sz.000608   -0.000351
# sz.000002    0.000470
# sz.000668   -0.000327
# sz.000402   -0.000227
# sz.000691   -0.000851
# sz.000560   -0.000574
# sz.000573   -0.001298
# dtype: float64

# %%
from numpy import mean
number_list = [-0.000458,  -0.000351, 0.000470,-0.000327,  -0.000227,-0.000851, -0.000574,-0.001298]
avg = mean(number_list)
print("The average is ", round(avg,10))
# Out:
# The average is  -0.000452

# %%
df = pd.read_excel('third period _group 2.xlsx',sheet_name = 'Sheet1')
df.mean()
# Out:
# sz.000007   -0.000416
# sz.000732   -0.000386
# sz.000965   -0.000723
# sz.000042   -0.000837
# sz.000615   -0.000687
# sz.000838   -0.001381
# sz.000656    0.000783
# sz.000517   -0.000455
# dtype: float64

# %%
from numpy import mean
number_list =[ -0.000416,  -0.000386, -0.000723, -0.000837,   -0.000687,-0.001381,  0.000783,-0.000455]
avg = mean(number_list)
print("The average is ", round(avg,10))
# Out:
# The average is  -0.00051275

# %%
df = pd.read_excel('third period _group 3.xlsx',sheet_name = 'Sheet1')
df.mean()
# Out:
# sz.000031   -0.000188
# sz.000069    0.000272
# sz.000616   -0.000948
# sz.000036   -0.000340
# sz.000046   -0.000929
# sz.000006   -0.000474
# sz.002133   -0.001057
# sz.000558   -0.001248
# dtype: float64

# %%
from numpy import mean
number_list =[ -0.000188,0.000272,-0.000948, -0.000340,-0.000929, -0.000474,-0.001057,-0.001248]
avg = mean(number_list)
print("The average is ", round(avg,10))
# Out:
# The average is  -0.000614

# %%
df = pd.read_excel('third period _group 4.xlsx',sheet_name = 'Sheet1')
df.mean()
# Out:
# sz.002016    0.000253
# sz.000514   -0.000661
# sz.000671    0.000310
# sz.000961    0.000050
# sz.002146    0.000514
# sz.000797   -0.000540
# sz.000897   -0.000891
# sz.000718   -0.000923
# dtype: float64

# %%
from numpy import mean
number_list =[ 0.000253,-0.000661,0.000310, 0.000050,0.000514, -0.000540,-0.000891,-0.000923]
avg = mean(number_list)
print("The average is ", round(avg,10))
# Out:
# The average is  -0.000236

# %%
df = pd.read_excel('third period _group 5.xlsx',sheet_name = 'Sheet1')
df.mean()
# Out:
# sz.002244   -0.000473
# sz.002285   -0.000813
# sz.000926   -0.000789
# sz.000631   -0.000570
# sz.002208   -0.000420
# sz.002147   -0.002433
# sz.000736   -0.000297
# sz.000043    0.001095
# dtype: float64

# %%
from numpy import mean
number_list =[-0.000473,-0.000813,-0.000789,-0.000570,-0.000420, -0.002433,-0.000297,0.001095]
avg = mean(number_list)
print("The average is ", round(avg,10))
# Out:
# The average is  -0.0005875

# %%
df = pd.read_excel('third period _group 6.xlsx',sheet_name = 'Sheet1')
df.mean()
# Out:
# sz.000502   -0.000966
# sz.002377   -0.001056
# sz.000540   -0.000273
# sz.000537   -0.000006
# sz.000014   -0.000798
# sz.000011   -0.000500
# sz.000909   -0.000869
# sz.002077   -0.001248
# dtype: float64

# %%
from numpy import mean
number_list =[ -0.000966, -0.001056, -0.000273, -0.000006,-0.000798, -0.000500,-0.000869,-0.001248]
avg = mean(number_list)
print("The average is ", round(avg,10))
# Out:
# The average is  -0.0007145

# %% [markdown]
# #### Run the regression between the five average stock returns and the betas obtained from the step 2

# %%
df = pd.read_excel('group beta and average return .xlsx',sheet_name = 'sheet1')
X = df['group_beta']
y = df['average_return']
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         average_return   R-squared:                       0.045
# Model:                            OLS   Adj. R-squared:                 -0.194
# Method:                 Least Squares   F-statistic:                    0.1887
# Date:                Sat, 28 Nov 2020   Prob (F-statistic):              0.686
# Time:                        17:30:06   Log-Likelihood:                 44.420
# No. Observations:                   6   AIC:                            -84.84
# Df Residuals:                       4   BIC:                            -85.26
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0002      0.001     -0.233      0.827      -0.002       0.002
# group_beta    -0.0003      0.001     -0.434      0.686      -0.002       0.002
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.251
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.518
# Skew:                           1.218   Prob(JB):                        0.468
# Kurtosis:                       3.378   Cond. No.                         21.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\Shane\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "

# %%
data = pd.read_excel('group beta and average return .xlsx',sheet_name = 'Sheet1')
y_var = ['average_return']
x_var = ['group_beta']
reg.OLS(reg_name = "regression", data = data, y_name = y_var, beta_names = x_var)
# reg.data

# %% [markdown]
# #### Finally we add the non-system risk to the regression equationSexual to further analyze whether the individual stock is compensated by the market with regards to the nonsystem risk.

# %% [markdown]
#                          R_pi=γ_0+γ_1 β_pi+γ_2 σ_pi+ε_i           (5)
#
# 𝜎𝑝𝑖 is the residual obtained from step 2.

# %%
df = pd.read_excel('group beta and average return .xlsx',sheet_name = 'sheet1')
X = df[['group_beta','r']]
y = df['average_return']
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         average_return   R-squared:                       0.738
# Model:                            OLS   Adj. R-squared:                  0.563
# Method:                 Least Squares   F-statistic:                     4.225
# Date:                Sat, 28 Nov 2020   Prob (F-statistic):              0.134
# Time:                        17:30:13   Log-Likelihood:                 48.299
# No. Observations:                   6   AIC:                            -90.60
# Df Residuals:                       3   BIC:                            -91.22
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0012      0.001     -1.979      0.142      -0.003       0.001
# group_beta    -0.0014      0.001     -2.367      0.099      -0.003       0.000
# r              0.1717      0.061      2.817      0.067      -0.022       0.366
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.530
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.439
# Skew:                          -0.484   Prob(JB):                        0.803
# Kurtosis:                       2.095   Cond. No.                     1.97e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.97e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# C:\Users\Shane\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "

# %% [markdown]
# #### Adding the quadratic variable and obtain another estimation regression:

# %% [markdown]
#                    R_pi=γ_0+γ_1 β_pi+γ_2 σ_pi+γ_3 β_pi^2+ε_i      (6)

# %% [markdown]
# #### Square the variable of group_beta

# %%
data = pd.read_excel('group beta and average return .xlsx',sheet_name = 'sheet1')
data['group_beta_square'] = data['group_beta'].pow(2)
data
# Out:
#    Unnamed: 0  group_beta  group_beta_square  r-squre         r  \
# 0           1      0.8357           0.698394    0.698  0.011038
# 1           2      0.9749           0.950430    0.719  0.011508
# 2           3      1.0875           1.182656    0.741  0.012909
# 3           4      1.0979           1.205384    0.718  0.013827
# 4           5      1.0634           1.130820    0.748  0.012404
# 5           6      1.1163           1.246126    0.791  0.011508
#
#    average_return
# 0       -0.000452
# 1       -0.000513
# 2       -0.000614
# 3       -0.000236
# 4       -0.000588
# 5       -0.000714

# %%
# df = pd.read_excel('group beta and average return .xlsx',sheet_name = 'sheet1')
df = data
X = df[['group_beta','group_beta_square']]
y = df['average_return']
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         average_return   R-squared:                       0.045
# Model:                            OLS   Adj. R-squared:                 -0.592
# Method:                 Least Squares   F-statistic:                   0.07080
# Date:                Sat, 28 Nov 2020   Prob (F-statistic):              0.933
# Time:                        17:30:24   Log-Likelihood:                 44.420
# No. Observations:                   6   AIC:                            -82.84
# Df Residuals:                       3   BIC:                            -83.46
# Df Model:                           2
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.0003      0.012     -0.023      0.983      -0.037       0.037
# group_beta           -0.0002      0.024     -0.007      0.995      -0.076       0.076
# group_beta_square  -8.71e-05      0.012     -0.007      0.995      -0.039       0.039
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.253
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.534
# Skew:                           1.223   Prob(JB):                        0.464
# Kurtosis:                       3.383   Cond. No.                         619.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\Shane\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
df = data
# df = pd.read_excel('group beta and average return .xlsx',sheet_name = 'sheet1')
X = df['r']
y = df['average_return']
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         average_return   R-squared:                       0.249
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     1.325
# Date:                Sat, 28 Nov 2020   Prob (F-statistic):              0.314
# Time:                        17:30:25   Log-Likelihood:                 45.139
# No. Observations:                   6   AIC:                            -86.28
# Df Residuals:                       4   BIC:                            -86.70
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0015      0.001     -1.769      0.152      -0.004       0.001
# r              0.0786      0.068      1.151      0.314      -0.111       0.268
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.032
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.777
# Skew:                           0.090   Prob(JB):                        0.678
# Kurtosis:                       1.247   Cond. No.                     1.04e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.04e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# C:\Users\Shane\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "

# %%
# df = pd.read_excel('group beta and average return .xlsx',sheet_name = 'sheet1')
df = data 
X = df[['r','group_beta','group_beta_square']]
y = df['average_return']
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
print(est.summary())


import fpdf

pdf = fpdf.FPDF(format='letter')
pdf.add_page()
pdf.set_font("Arial", size=8)

for i in str(est.summary()):
    pdf.write(5,i)
pdf.output("testings.pdf")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         average_return   R-squared:                       0.739
# Model:                            OLS   Adj. R-squared:                  0.347
# Method:                 Least Squares   F-statistic:                     1.887
# Date:                Sat, 28 Nov 2020   Prob (F-statistic):              0.365
# Time:                        19:00:10   Log-Likelihood:                 48.310
# No. Observations:                   6   AIC:                            -88.62
# Df Residuals:                       2   BIC:                            -89.45
# Df Model:                           3
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.0005      0.007     -0.071      0.950      -0.032       0.031
# r                     0.1720      0.075      2.306      0.148      -0.149       0.493
# group_beta           -0.0027      0.015     -0.178      0.875      -0.069       0.063
# group_beta_square     0.0007      0.008      0.086      0.939      -0.033       0.035
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.568
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.447
# Skew:                          -0.488   Prob(JB):                        0.800
# Kurtosis:                       2.087   Cond. No.                     2.46e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# C:\Users\Shane\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\Users\Shane\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# ''
